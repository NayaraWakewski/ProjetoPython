# %%
#Importação das Bibliotecas
import requests
import pandas as pd
from sqlalchemy import create_engine, inspect, text
import logging
from sqlalchemy.exc import SQLAlchemyError

# %%
# Configuração do logging para registrar mensagens de informação
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# %%
# URLs das APIs de onde os dados serão obtidos
url_contratos = 'https://api-dados-abertos.cearatransparente.ce.gov.br/transparencia/contratos/contratos'
url_convenios = 'https://api-dados-abertos.cearatransparente.ce.gov.br/transparencia/contratos/convenios'

# %%
# Configuração do engine do SQLAlchemy para o PostgreSQL
engine = create_engine('postgresql://airflow:airflow@127.0.0.1:5432/airflow', echo=False)

# %%
# Função para obter dados de uma URL
def obter_dados(url, num_paginas):
    # Inicializa uma lista vazia para armazenar todos os dados obtidos
    todos_os_dados = []
    
    # Loop sobre o número de páginas especificado
    for pagina in range(1, num_paginas + 1):
        parametros = {'page': pagina}
        
        # Faz uma requisição GET para a URL especificada com os parâmetros da página
        resposta = requests.get(url, params=parametros, headers={'accept': 'application/json'}, timeout=30)
        
        # Verifica se a resposta da requisição foi bem-sucedida (status code 200)
        if resposta.status_code == 200:
            # Extrai os dados da resposta no formato JSON
            dados = resposta.json()
            
            # Verifica se não há mais dados a serem obtidos, e encerra o loop nesse caso
            if not dados['data']:
                break
            
            # Adiciona os dados obtidos à lista de todos os dados
            todos_os_dados.extend(dados['data'])
            logging.info(f'Página {pagina}/{num_paginas} processada.')
        else:
            # Registra um erro se a requisição não foi bem-sucedida e retorna um DataFrame vazio
            logging.error(f'Erro na requisição: {resposta.status_code}')
            return pd.DataFrame()
    
    # Converte a lista de todos os dados em um DataFrame e retorna
    return pd.DataFrame(todos_os_dados)

# %%
# Função para criar um schema no banco de dados se ele não existir
def criar_schema_se_nao_existir(engine, schema):
    try:
        # Conecta-se ao banco de dados usando o engine especificado
        with engine.connect() as conn:
            # Cria uma query SQL para criar o schema se ele não existir
            query = f"CREATE SCHEMA IF NOT EXISTS {schema};"
            
            # Executa a query no banco de dados
            conn.execute(query)
            
            # Registra uma mensagem de informação se o schema foi criado com sucesso
            logging.info(f'Schema {schema} criado com sucesso.')
    except SQLAlchemyError as e:
        # Registra um erro se ocorrer algum problema ao criar o schema
        logging.error(f'Erro ao verificar ou criar o schema {schema}: {e}')

# %%
# Função para criar uma tabela no banco de dados se ela não existir
def criar_tabela_se_nao_existir(engine, nome_tabela, schema, df):
    # Cria um inspetor para verificar a existência da tabela
    inspector = inspect(engine)
    
    # Verifica se a tabela não existe
    if not inspector.has_table(nome_tabela, schema=schema):
        # Registra uma mensagem de informação se a tabela não existe e será criada
        logging.info(f'A tabela {nome_tabela} não existe. Criando...')
        
        # Cria uma tabela vazia com a estrutura do DataFrame fornecido
        df.head(0).to_sql(nome_tabela, engine, schema=schema, index=False)
    else:
        # Registra uma mensagem de informação se a tabela já existe
        logging.info(f'A tabela {nome_tabela} já existe.')

# %%
# Função para verificar se existem dados duplicados em uma tabela
def verificar_dados_existentes(engine, nome_tabela, schema, df, colunas_chave_unica):
    try:
        # Conecta-se ao banco de dados usando o engine especificado
        with engine.connect() as conn:
            # Constrói uma consulta SQL para verificar a existência de dados duplicados
            condicoes = " AND ".join([f"{col}='{df[col].iloc[0]}'" for col in colunas_chave_unica])
            sql = f"SELECT COUNT(*) FROM {schema}.{nome_tabela} WHERE {condicoes};"
            
            # Executa a consulta SQL
            result = conn.execute(text(sql))
            
            # Obtém o número de linhas retornadas pela consulta
            row_count = result.fetchone()[0]
            
            # Retorna True se os dados existirem, False caso contrário
            return row_count > 0
    except SQLAlchemyError as e:
        # Registra um erro se ocorrer algum problema ao verificar os dados duplicados
        logging.error(f'Erro ao verificar dados existentes na tabela {schema}.{nome_tabela}: {e}')
        return False

# %%
# Função para criar uma tabela e inserir dados nela usando uma tabela temporária
def criar_tabela_e_inserir_dados_com_tabela_temporaria(df, nome_tabela, engine, colunas_chave_unica, schema='stage'):
    # Verifica se o DataFrame está vazio
    if df.empty:
        # Registra uma mensagem de informação se o DataFrame estiver vazio
        logging.info(f'Nenhum dado disponível para a tabela {nome_tabela}.')
        return

    # Define os nomes da tabela temporária e da tabela definitiva
    nome_tabela_temporaria = f"{nome_tabela}_temp_{schema}"
    nome_tabela_definitiva = f"{nome_tabela}"

    try:
        # Insere os dados na tabela temporária apenas se eles não existirem na tabela definitiva
        if not verificar_dados_existentes(engine, nome_tabela_definitiva, schema, df, colunas_chave_unica):
            # Insere os dados na tabela temporária
            df.to_sql(nome_tabela_temporaria, engine, if_exists='replace', index=False, schema=schema)
            logging.info(f'Dados inseridos na tabela temporária {schema}.{nome_tabela_temporaria}.')

            # Tenta inserir os dados na tabela definitiva
            with engine.begin() as conn:
                df.to_sql(nome_tabela_definitiva, engine, if_exists='append', index=False, schema=schema, method='multi')
                logging.info(f'Dados inseridos na tabela {schema}.{nome_tabela_definitiva} com sucesso.')

            # Remove a tabela temporária após a inserção
            with engine.begin() as conn:
                query = f'DROP TABLE IF EXISTS "{schema}"."{nome_tabela_temporaria}";'
                conn.execute(text(query))
                logging.info(f'Tabela temporária {schema}.{nome_tabela_temporaria} removida com sucesso.')
        else:
            # Registra uma mensagem de informação se os dados já existirem na tabela definitiva
            logging.info(f'Dados já existentes na tabela {schema}.{nome_tabela_definitiva}. Nenhuma inserção foi realizada.')
    except SQLAlchemyError as e:
        # Registra um erro se ocorrer algum problema ao inserir dados na tabela definitiva
        logging.error(f'Erro ao inserir dados na tabela {schema}.{nome_tabela_definitiva}: {e}')

# %%
#Lógica Principal do Script - onde executará as funções.
if __name__ == "__main__":
    # Cria o schema 'stage' se ele não existir
    criar_schema_se_nao_existir(engine, 'stage')
    
    # Obtém os dados dos contratos e dos convênios
    df_contratos = obter_dados(url_contratos, 500)
    df_convenios = obter_dados(url_convenios, 500)
    
    # Define as colunas de chave única para os contratos e convênios
    colunas_chave_unica_contratos = ['cpf_cnpj_financiador', 'num_contrato', 'data_assinatura']
    colunas_chave_unica_convenios = ['cpf_cnpj_financiador', 'num_contrato', 'data_assinatura']

    # Cria as tabelas 'contratos' e 'convenios' se elas não existirem
    criar_tabela_se_nao_existir(engine, 'contratos', 'stage', df_contratos)
    criar_tabela_se_nao_existir(engine, 'convenios', 'stage', df_convenios)

    # Cria e insere dados nas tabelas 'contratos' e 'convenios' usando tabelas temporárias
    criar_tabela_e_inserir_dados_com_tabela_temporaria(df_contratos, 'contratos', engine, colunas_chave_unica_contratos)
    criar_tabela_e_inserir_dados_com_tabela_temporaria(df_convenios, 'convenios', engine, colunas_chave_unica_convenios)
# Out:
# 2024-04-08 19:27:03,840 - ERROR - Erro ao verificar ou criar o schema stage: Not an executable object: 'CREATE SCHEMA IF NOT EXISTS stage;'
# 2024-04-08 19:27:05,134 - INFO - Página 1/500 processada.
# 2024-04-08 19:27:06,398 - INFO - Página 2/500 processada.
# 2024-04-08 19:27:07,582 - INFO - Página 3/500 processada.
# 2024-04-08 19:27:08,844 - INFO - Página 4/500 processada.
# 2024-04-08 19:27:09,969 - INFO - Página 5/500 processada.
# 2024-04-08 19:27:11,177 - INFO - Página 6/500 processada.
# 2024-04-08 19:27:12,308 - INFO - Página 7/500 processada.
# 2024-04-08 19:27:13,312 - INFO - Página 8/500 processada.
# 2024-04-08 19:27:14,451 - INFO - Página 9/500 processada.
# 2024-04-08 19:27:15,578 - INFO - Página 10/500 processada.
# 2024-04-08 19:27:16,611 - INFO - Página 11/500 processada.
# 2024-04-08 19:27:17,735 - INFO - Página 12/500 processada.
# 2024-04-08 19:27:18,996 - INFO - Página 13/500 processada.
# 2024-04-08 19:27:20,188 - INFO - Página 14/500 processada.
# 2024-04-08 19:27:21,832 - INFO - Página 15/500 processada.
# 2024-04-08 19:27:22,847 - INFO - Página 16/500 processada.
# 2024-04-08 19:27:23,880 - INFO - Página 17/500 processada.
# 2024-04-08 19:27:24,929 - INFO - Página 18/500 processada.
# 2024-04-08 19:27:25,925 - INFO - Página 19/500 processada.
# 2024-04-08 19:27:27,059 - INFO - Página 20/500 processada.
# 2024-04-08 19:27:28,205 - INFO - Página 21/500 processada.
# 2024-04-08 19:27:29,431 - INFO - Página 22/500 processada.
# 2024-04-08 19:27:30,430 - INFO - Página 23/500 processada.
# 2024-04-08 19:27:31,992 - INFO - Página 24/500 processada.
# 2024-04-08 19:27:33,521 - INFO - Página 25/500 processada.
# 2024-04-08 19:27:35,084 - INFO - Página 26/500 processada.
# 2024-04-08 19:27:36,595 - INFO - Página 27/500 processada.
# 2024-04-08 19:27:37,636 - INFO - Página 28/500 processada.
# 2024-04-08 19:27:38,723 - INFO - Página 29/500 processada.
# 2024-04-08 19:27:39,983 - INFO - Página 30/500 processada.
# 2024-04-08 19:27:41,100 - INFO - Página 31/500 processada.
# 2024-04-08 19:27:42,786 - INFO - Página 32/500 processada.
# 2024-04-08 19:27:43,948 - INFO - Página 33/500 processada.
# 2024-04-08 19:27:44,998 - INFO - Página 34/500 processada.
# 2024-04-08 19:27:46,111 - INFO - Página 35/500 processada.
# 2024-04-08 19:27:47,332 - INFO - Página 36/500 processada.
# 2024-04-08 19:27:48,559 - INFO - Página 37/500 processada.
# 2024-04-08 19:27:49,795 - INFO - Página 38/500 processada.
# 2024-04-08 19:27:50,908 - INFO - Página 39/500 processada.
# 2024-04-08 19:27:52,134 - INFO - Página 40/500 processada.
# 2024-04-08 19:27:53,294 - INFO - Página 41/500 processada.
# 2024-04-08 19:27:54,291 - INFO - Página 42/500 processada.
# 2024-04-08 19:27:55,329 - INFO - Página 43/500 processada.
# 2024-04-08 19:27:56,441 - INFO - Página 44/500 processada.
# 2024-04-08 19:27:57,658 - INFO - Página 45/500 processada.
# 2024-04-08 19:27:58,742 - INFO - Página 46/500 processada.
# 2024-04-08 19:27:59,959 - INFO - Página 47/500 processada.
# 2024-04-08 19:28:01,498 - INFO - Página 48/500 processada.
# 2024-04-08 19:28:02,741 - INFO - Página 49/500 processada.
# 2024-04-08 19:28:03,864 - INFO - Página 50/500 processada.
# 2024-04-08 19:28:05,223 - INFO - Página 51/500 processada.
# 2024-04-08 19:28:06,337 - INFO - Página 52/500 processada.
# 2024-04-08 19:28:07,499 - INFO - Página 53/500 processada.
# 2024-04-08 19:28:08,744 - INFO - Página 54/500 processada.
# 2024-04-08 19:28:09,699 - INFO - Página 55/500 processada.
# 2024-04-08 19:28:11,090 - INFO - Página 56/500 processada.
# 2024-04-08 19:28:12,372 - INFO - Página 57/500 processada.
# 2024-04-08 19:28:13,715 - INFO - Página 58/500 processada.
# 2024-04-08 19:28:15,123 - INFO - Página 59/500 processada.
# 2024-04-08 19:28:16,533 - INFO - Página 60/500 processada.
# 2024-04-08 19:28:17,813 - INFO - Página 61/500 processada.
# 2024-04-08 19:28:18,991 - INFO - Página 62/500 processada.
# 2024-04-08 19:28:20,395 - INFO - Página 63/500 processada.
# 2024-04-08 19:28:21,643 - INFO - Página 64/500 processada.
# 2024-04-08 19:28:22,809 - INFO - Página 65/500 processada.
# 2024-04-08 19:28:24,130 - INFO - Página 66/500 processada.
# 2024-04-08 19:28:25,123 - INFO - Página 67/500 processada.
# 2024-04-08 19:28:26,232 - INFO - Página 68/500 processada.
# 2024-04-08 19:28:27,580 - INFO - Página 69/500 processada.
# 2024-04-08 19:28:29,026 - INFO - Página 70/500 processada.
# 2024-04-08 19:28:30,006 - INFO - Página 71/500 processada.
# 2024-04-08 19:28:31,161 - INFO - Página 72/500 processada.
# 2024-04-08 19:28:32,456 - INFO - Página 73/500 processada.
# 2024-04-08 19:28:33,715 - INFO - Página 74/500 processada.
# 2024-04-08 19:28:34,775 - INFO - Página 75/500 processada.
# 2024-04-08 19:28:35,942 - INFO - Página 76/500 processada.
# 2024-04-08 19:28:36,907 - INFO - Página 77/500 processada.
# 2024-04-08 19:28:38,110 - INFO - Página 78/500 processada.
# 2024-04-08 19:28:39,446 - INFO - Página 79/500 processada.
# 2024-04-08 19:28:40,592 - INFO - Página 80/500 processada.
# 2024-04-08 19:28:41,655 - INFO - Página 81/500 processada.
# 2024-04-08 19:28:42,729 - INFO - Página 82/500 processada.
# 2024-04-08 19:28:43,728 - INFO - Página 83/500 processada.
# 2024-04-08 19:28:44,877 - INFO - Página 84/500 processada.
# 2024-04-08 19:28:45,929 - INFO - Página 85/500 processada.
# 2024-04-08 19:28:46,918 - INFO - Página 86/500 processada.
# 2024-04-08 19:28:48,177 - INFO - Página 87/500 processada.
# 2024-04-08 19:28:49,356 - INFO - Página 88/500 processada.
# 2024-04-08 19:28:50,548 - INFO - Página 89/500 processada.
# 2024-04-08 19:28:51,638 - INFO - Página 90/500 processada.
# 2024-04-08 19:28:52,785 - INFO - Página 91/500 processada.
# 2024-04-08 19:28:53,910 - INFO - Página 92/500 processada.
# 2024-04-08 19:28:55,233 - INFO - Página 93/500 processada.
# 2024-04-08 19:28:56,350 - INFO - Página 94/500 processada.
# 2024-04-08 19:28:57,478 - INFO - Página 95/500 processada.
# 2024-04-08 19:28:58,508 - INFO - Página 96/500 processada.
# 2024-04-08 19:28:59,937 - INFO - Página 97/500 processada.
# 2024-04-08 19:29:01,057 - INFO - Página 98/500 processada.
# 2024-04-08 19:29:02,088 - INFO - Página 99/500 processada.
# 2024-04-08 19:29:03,109 - INFO - Página 100/500 processada.
# 2024-04-08 19:29:04,440 - INFO - Página 101/500 processada.
# 2024-04-08 19:29:05,682 - INFO - Página 102/500 processada.
# 2024-04-08 19:29:07,099 - INFO - Página 103/500 processada.
# 2024-04-08 19:29:08,436 - INFO - Página 104/500 processada.
# 2024-04-08 19:29:09,976 - INFO - Página 105/500 processada.
# 2024-04-08 19:29:11,545 - INFO - Página 106/500 processada.
# 2024-04-08 19:29:12,782 - INFO - Página 107/500 processada.
# 2024-04-08 19:29:13,829 - INFO - Página 108/500 processada.
# 2024-04-08 19:29:14,857 - INFO - Página 109/500 processada.
# 2024-04-08 19:29:16,462 - INFO - Página 110/500 processada.
# 2024-04-08 19:29:17,515 - INFO - Página 111/500 processada.
# 2024-04-08 19:29:18,560 - INFO - Página 112/500 processada.
# 2024-04-08 19:29:19,840 - INFO - Página 113/500 processada.
# 2024-04-08 19:29:21,049 - INFO - Página 114/500 processada.
# 2024-04-08 19:29:22,709 - INFO - Página 115/500 processada.
# 2024-04-08 19:29:23,921 - INFO - Página 116/500 processada.
# 2024-04-08 19:29:25,288 - INFO - Página 117/500 processada.
# 2024-04-08 19:29:26,944 - INFO - Página 118/500 processada.
# 2024-04-08 19:29:28,134 - INFO - Página 119/500 processada.
# 2024-04-08 19:29:29,477 - INFO - Página 120/500 processada.
# 2024-04-08 19:29:30,554 - INFO - Página 121/500 processada.
# 2024-04-08 19:29:31,827 - INFO - Página 122/500 processada.
# 2024-04-08 19:29:33,071 - INFO - Página 123/500 processada.
# 2024-04-08 19:29:34,568 - INFO - Página 124/500 processada.
# 2024-04-08 19:29:35,744 - INFO - Página 125/500 processada.
# 2024-04-08 19:29:37,007 - INFO - Página 126/500 processada.
# 2024-04-08 19:29:38,227 - INFO - Página 127/500 processada.
# 2024-04-08 19:29:39,804 - INFO - Página 128/500 processada.
# 2024-04-08 19:29:41,446 - INFO - Página 129/500 processada.
# 2024-04-08 19:29:42,692 - INFO - Página 130/500 processada.
# 2024-04-08 19:29:43,992 - INFO - Página 131/500 processada.
# 2024-04-08 19:29:45,300 - INFO - Página 132/500 processada.
# 2024-04-08 19:29:46,396 - INFO - Página 133/500 processada.
# 2024-04-08 19:29:47,757 - INFO - Página 134/500 processada.
# 2024-04-08 19:29:48,991 - INFO - Página 135/500 processada.
# 2024-04-08 19:29:50,223 - INFO - Página 136/500 processada.
# 2024-04-08 19:29:51,307 - INFO - Página 137/500 processada.
# 2024-04-08 19:29:52,366 - INFO - Página 138/500 processada.
# 2024-04-08 19:29:53,381 - INFO - Página 139/500 processada.
# 2024-04-08 19:29:54,606 - INFO - Página 140/500 processada.
# 2024-04-08 19:29:55,819 - INFO - Página 141/500 processada.
# 2024-04-08 19:29:56,974 - INFO - Página 142/500 processada.
# 2024-04-08 19:29:58,525 - INFO - Página 143/500 processada.
# 2024-04-08 19:29:59,791 - INFO - Página 144/500 processada.
# 2024-04-08 19:30:01,075 - INFO - Página 145/500 processada.
# 2024-04-08 19:30:02,715 - INFO - Página 146/500 processada.
# 2024-04-08 19:30:04,106 - INFO - Página 147/500 processada.
# 2024-04-08 19:30:05,581 - INFO - Página 148/500 processada.
# 2024-04-08 19:30:07,170 - INFO - Página 149/500 processada.
# 2024-04-08 19:30:08,380 - INFO - Página 150/500 processada.
# 2024-04-08 19:30:09,640 - INFO - Página 151/500 processada.
# 2024-04-08 19:30:11,114 - INFO - Página 152/500 processada.
# 2024-04-08 19:30:12,328 - INFO - Página 153/500 processada.
# 2024-04-08 19:30:13,588 - INFO - Página 154/500 processada.
# 2024-04-08 19:30:14,725 - INFO - Página 155/500 processada.
# 2024-04-08 19:30:15,743 - INFO - Página 156/500 processada.
# 2024-04-08 19:30:16,792 - INFO - Página 157/500 processada.
# 2024-04-08 19:30:17,978 - INFO - Página 158/500 processada.
# 2024-04-08 19:30:19,290 - INFO - Página 159/500 processada.
# 2024-04-08 19:30:20,561 - INFO - Página 160/500 processada.
# 2024-04-08 19:30:21,732 - INFO - Página 161/500 processada.
# 2024-04-08 19:30:23,094 - INFO - Página 162/500 processada.
# 2024-04-08 19:30:24,227 - INFO - Página 163/500 processada.
# 2024-04-08 19:30:25,346 - INFO - Página 164/500 processada.
# 2024-04-08 19:30:26,346 - INFO - Página 165/500 processada.
# 2024-04-08 19:30:27,618 - INFO - Página 166/500 processada.
# 2024-04-08 19:30:29,264 - INFO - Página 167/500 processada.
# 2024-04-08 19:30:30,572 - INFO - Página 168/500 processada.
# 2024-04-08 19:30:31,723 - INFO - Página 169/500 processada.
# 2024-04-08 19:30:32,834 - INFO - Página 170/500 processada.
# 2024-04-08 19:30:33,955 - INFO - Página 171/500 processada.
# 2024-04-08 19:30:35,087 - INFO - Página 172/500 processada.
# 2024-04-08 19:30:36,123 - INFO - Página 173/500 processada.
# 2024-04-08 19:30:37,265 - INFO - Página 174/500 processada.
# 2024-04-08 19:30:38,279 - INFO - Página 175/500 processada.
# 2024-04-08 19:30:39,594 - INFO - Página 176/500 processada.
# 2024-04-08 19:30:40,910 - INFO - Página 177/500 processada.
# 2024-04-08 19:30:42,274 - INFO - Página 178/500 processada.
# 2024-04-08 19:30:43,731 - INFO - Página 179/500 processada.
# 2024-04-08 19:30:45,224 - INFO - Página 180/500 processada.
# 2024-04-08 19:30:46,908 - INFO - Página 181/500 processada.
# 2024-04-08 19:30:47,913 - INFO - Página 182/500 processada.
# 2024-04-08 19:30:49,226 - INFO - Página 183/500 processada.
# 2024-04-08 19:30:50,239 - INFO - Página 184/500 processada.
# 2024-04-08 19:30:51,389 - INFO - Página 185/500 processada.
# 2024-04-08 19:30:52,423 - INFO - Página 186/500 processada.
# 2024-04-08 19:30:53,600 - INFO - Página 187/500 processada.
# 2024-04-08 19:30:54,610 - INFO - Página 188/500 processada.
# 2024-04-08 19:30:55,822 - INFO - Página 189/500 processada.
# 2024-04-08 19:30:56,994 - INFO - Página 190/500 processada.
# 2024-04-08 19:30:58,249 - INFO - Página 191/500 processada.
# 2024-04-08 19:30:59,427 - INFO - Página 192/500 processada.
# 2024-04-08 19:31:00,677 - INFO - Página 193/500 processada.
# 2024-04-08 19:31:02,002 - INFO - Página 194/500 processada.
# 2024-04-08 19:31:03,305 - INFO - Página 195/500 processada.
# 2024-04-08 19:31:04,464 - INFO - Página 196/500 processada.
# 2024-04-08 19:31:05,670 - INFO - Página 197/500 processada.
# 2024-04-08 19:31:06,925 - INFO - Página 198/500 processada.
# 2024-04-08 19:31:08,269 - INFO - Página 199/500 processada.
# 2024-04-08 19:31:09,476 - INFO - Página 200/500 processada.
# 2024-04-08 19:31:10,726 - INFO - Página 201/500 processada.
# 2024-04-08 19:31:11,872 - INFO - Página 202/500 processada.
# 2024-04-08 19:31:13,047 - INFO - Página 203/500 processada.
# 2024-04-08 19:31:14,729 - INFO - Página 204/500 processada.
# 2024-04-08 19:31:15,972 - INFO - Página 205/500 processada.
# 2024-04-08 19:31:17,157 - INFO - Página 206/500 processada.
# 2024-04-08 19:31:18,727 - INFO - Página 207/500 processada.
# 2024-04-08 19:31:20,159 - INFO - Página 208/500 processada.
# 2024-04-08 19:31:21,525 - INFO - Página 209/500 processada.
# 2024-04-08 19:31:22,595 - INFO - Página 210/500 processada.
# 2024-04-08 19:31:23,645 - INFO - Página 211/500 processada.
# 2024-04-08 19:31:24,766 - INFO - Página 212/500 processada.
# 2024-04-08 19:31:25,898 - INFO - Página 213/500 processada.
# 2024-04-08 19:31:27,320 - INFO - Página 214/500 processada.
# 2024-04-08 19:31:28,454 - INFO - Página 215/500 processada.
# 2024-04-08 19:31:29,688 - INFO - Página 216/500 processada.
# 2024-04-08 19:31:30,850 - INFO - Página 217/500 processada.
# 2024-04-08 19:31:31,923 - INFO - Página 218/500 processada.
# 2024-04-08 19:31:33,086 - INFO - Página 219/500 processada.
# 2024-04-08 19:31:34,176 - INFO - Página 220/500 processada.
# 2024-04-08 19:31:35,335 - INFO - Página 221/500 processada.
# 2024-04-08 19:31:36,850 - INFO - Página 222/500 processada.
# 2024-04-08 19:31:38,049 - INFO - Página 223/500 processada.
# 2024-04-08 19:31:39,287 - INFO - Página 224/500 processada.
# 2024-04-08 19:31:40,614 - INFO - Página 225/500 processada.
# 2024-04-08 19:31:41,695 - INFO - Página 226/500 processada.
# 2024-04-08 19:31:42,859 - INFO - Página 227/500 processada.
# 2024-04-08 19:31:43,981 - INFO - Página 228/500 processada.
# 2024-04-08 19:31:45,128 - INFO - Página 229/500 processada.
# 2024-04-08 19:31:46,240 - INFO - Página 230/500 processada.
# 2024-04-08 19:31:47,379 - INFO - Página 231/500 processada.
# 2024-04-08 19:31:48,824 - INFO - Página 232/500 processada.
# 2024-04-08 19:31:49,929 - INFO - Página 233/500 processada.
# 2024-04-08 19:31:51,143 - INFO - Página 234/500 processada.
# 2024-04-08 19:31:52,265 - INFO - Página 235/500 processada.
# 2024-04-08 19:31:53,577 - INFO - Página 236/500 processada.
# 2024-04-08 19:31:54,823 - INFO - Página 237/500 processada.
# 2024-04-08 19:31:55,971 - INFO - Página 238/500 processada.
# 2024-04-08 19:31:57,123 - INFO - Página 239/500 processada.
# 2024-04-08 19:31:58,498 - INFO - Página 240/500 processada.
# 2024-04-08 19:31:59,665 - INFO - Página 241/500 processada.
# 2024-04-08 19:32:00,660 - INFO - Página 242/500 processada.
# 2024-04-08 19:32:01,804 - INFO - Página 243/500 processada.
# 2024-04-08 19:32:03,215 - INFO - Página 244/500 processada.
# 2024-04-08 19:32:04,289 - INFO - Página 245/500 processada.
# 2024-04-08 19:32:05,705 - INFO - Página 246/500 processada.
# 2024-04-08 19:32:06,925 - INFO - Página 247/500 processada.
# 2024-04-08 19:32:08,148 - INFO - Página 248/500 processada.
# 2024-04-08 19:32:09,393 - INFO - Página 249/500 processada.
# 2024-04-08 19:32:10,593 - INFO - Página 250/500 processada.
# 2024-04-08 19:32:11,733 - INFO - Página 251/500 processada.
# 2024-04-08 19:32:12,861 - INFO - Página 252/500 processada.
# 2024-04-08 19:32:13,988 - INFO - Página 253/500 processada.
# 2024-04-08 19:32:15,015 - INFO - Página 254/500 processada.
# 2024-04-08 19:32:16,135 - INFO - Página 255/500 processada.
# 2024-04-08 19:32:17,322 - INFO - Página 256/500 processada.
# 2024-04-08 19:32:18,610 - INFO - Página 257/500 processada.
# 2024-04-08 19:32:19,719 - INFO - Página 258/500 processada.
# 2024-04-08 19:32:20,801 - INFO - Página 259/500 processada.
# 2024-04-08 19:32:21,972 - INFO - Página 260/500 processada.
# 2024-04-08 19:32:23,509 - INFO - Página 261/500 processada.
# 2024-04-08 19:32:24,511 - INFO - Página 262/500 processada.
# 2024-04-08 19:32:25,676 - INFO - Página 263/500 processada.
# 2024-04-08 19:32:26,676 - INFO - Página 264/500 processada.
# 2024-04-08 19:32:28,034 - INFO - Página 265/500 processada.
# 2024-04-08 19:32:29,275 - INFO - Página 266/500 processada.
# 2024-04-08 19:32:30,363 - INFO - Página 267/500 processada.
# 2024-04-08 19:32:31,659 - INFO - Página 268/500 processada.
# 2024-04-08 19:32:32,729 - INFO - Página 269/500 processada.
# 2024-04-08 19:32:33,870 - INFO - Página 270/500 processada.
# 2024-04-08 19:32:34,909 - INFO - Página 271/500 processada.
# 2024-04-08 19:32:36,422 - INFO - Página 272/500 processada.
# 2024-04-08 19:32:37,985 - INFO - Página 273/500 processada.
# 2024-04-08 19:32:39,409 - INFO - Página 274/500 processada.
# 2024-04-08 19:32:40,523 - INFO - Página 275/500 processada.
# 2024-04-08 19:32:41,585 - INFO - Página 276/500 processada.
# 2024-04-08 19:32:42,698 - INFO - Página 277/500 processada.
# 2024-04-08 19:32:43,806 - INFO - Página 278/500 processada.
# 2024-04-08 19:32:44,937 - INFO - Página 279/500 processada.
# 2024-04-08 19:32:45,956 - INFO - Página 280/500 processada.
# 2024-04-08 19:32:47,104 - INFO - Página 281/500 processada.
# 2024-04-08 19:32:48,305 - INFO - Página 282/500 processada.
# 2024-04-08 19:32:49,356 - INFO - Página 283/500 processada.
# 2024-04-08 19:32:50,371 - INFO - Página 284/500 processada.
# 2024-04-08 19:32:51,469 - INFO - Página 285/500 processada.
# 2024-04-08 19:32:52,708 - INFO - Página 286/500 processada.
# 2024-04-08 19:32:53,802 - INFO - Página 287/500 processada.
# 2024-04-08 19:32:55,414 - INFO - Página 288/500 processada.
# 2024-04-08 19:32:56,690 - INFO - Página 289/500 processada.
# 2024-04-08 19:32:57,724 - INFO - Página 290/500 processada.
# 2024-04-08 19:32:58,881 - INFO - Página 291/500 processada.
# 2024-04-08 19:33:00,269 - INFO - Página 292/500 processada.
# 2024-04-08 19:33:01,601 - INFO - Página 293/500 processada.
# 2024-04-08 19:33:02,631 - INFO - Página 294/500 processada.
# 2024-04-08 19:33:03,639 - INFO - Página 295/500 processada.
# 2024-04-08 19:33:04,784 - INFO - Página 296/500 processada.
# 2024-04-08 19:33:06,027 - INFO - Página 297/500 processada.
# 2024-04-08 19:33:07,437 - INFO - Página 298/500 processada.
# 2024-04-08 19:33:08,651 - INFO - Página 299/500 processada.
# 2024-04-08 19:33:09,883 - INFO - Página 300/500 processada.
# 2024-04-08 19:33:11,127 - INFO - Página 301/500 processada.
# 2024-04-08 19:33:12,221 - INFO - Página 302/500 processada.
# 2024-04-08 19:33:13,236 - INFO - Página 303/500 processada.
# 2024-04-08 19:33:14,378 - INFO - Página 304/500 processada.
# 2024-04-08 19:33:15,722 - INFO - Página 305/500 processada.
# 2024-04-08 19:33:16,879 - INFO - Página 306/500 processada.
# 2024-04-08 19:33:17,870 - INFO - Página 307/500 processada.
# 2024-04-08 19:33:19,033 - INFO - Página 308/500 processada.
# 2024-04-08 19:33:20,310 - INFO - Página 309/500 processada.
# 2024-04-08 19:33:21,498 - INFO - Página 310/500 processada.
# 2024-04-08 19:33:22,501 - INFO - Página 311/500 processada.
# 2024-04-08 19:33:23,714 - INFO - Página 312/500 processada.
# 2024-04-08 19:33:24,989 - INFO - Página 313/500 processada.
# 2024-04-08 19:33:26,492 - INFO - Página 314/500 processada.
# 2024-04-08 19:33:27,617 - INFO - Página 315/500 processada.
# 2024-04-08 19:33:28,638 - INFO - Página 316/500 processada.
# 2024-04-08 19:33:29,676 - INFO - Página 317/500 processada.
# 2024-04-08 19:33:30,789 - INFO - Página 318/500 processada.
# 2024-04-08 19:33:32,325 - INFO - Página 319/500 processada.
# 2024-04-08 19:33:33,490 - INFO - Página 320/500 processada.
# 2024-04-08 19:33:34,776 - INFO - Página 321/500 processada.
# 2024-04-08 19:33:35,920 - INFO - Página 322/500 processada.
# 2024-04-08 19:33:37,035 - INFO - Página 323/500 processada.
# 2024-04-08 19:33:38,456 - INFO - Página 324/500 processada.
# 2024-04-08 19:33:39,595 - INFO - Página 325/500 processada.
# 2024-04-08 19:33:40,916 - INFO - Página 326/500 processada.
# 2024-04-08 19:33:42,161 - INFO - Página 327/500 processada.
# 2024-04-08 19:33:43,671 - INFO - Página 328/500 processada.
# 2024-04-08 19:33:44,717 - INFO - Página 329/500 processada.
# 2024-04-08 19:33:45,738 - INFO - Página 330/500 processada.
# 2024-04-08 19:33:47,074 - INFO - Página 331/500 processada.
# 2024-04-08 19:33:48,193 - INFO - Página 332/500 processada.
# 2024-04-08 19:33:49,424 - INFO - Página 333/500 processada.
# 2024-04-08 19:33:50,552 - INFO - Página 334/500 processada.
# 2024-04-08 19:33:51,695 - INFO - Página 335/500 processada.
# 2024-04-08 19:33:52,897 - INFO - Página 336/500 processada.
# 2024-04-08 19:33:54,031 - INFO - Página 337/500 processada.
# 2024-04-08 19:33:55,038 - INFO - Página 338/500 processada.
# 2024-04-08 19:33:56,238 - INFO - Página 339/500 processada.
# 2024-04-08 19:33:57,303 - INFO - Página 340/500 processada.
# 2024-04-08 19:33:58,624 - INFO - Página 341/500 processada.
# 2024-04-08 19:33:59,679 - INFO - Página 342/500 processada.
# 2024-04-08 19:34:00,768 - INFO - Página 343/500 processada.
# 2024-04-08 19:34:02,136 - INFO - Página 344/500 processada.
# 2024-04-08 19:34:03,139 - INFO - Página 345/500 processada.
# 2024-04-08 19:34:04,352 - INFO - Página 346/500 processada.
# 2024-04-08 19:34:05,538 - INFO - Página 347/500 processada.
# 2024-04-08 19:34:06,619 - INFO - Página 348/500 processada.
# 2024-04-08 19:34:07,542 - INFO - Página 349/500 processada.
# 2024-04-08 19:34:08,657 - INFO - Página 350/500 processada.
# 2024-04-08 19:34:09,694 - INFO - Página 351/500 processada.
# 2024-04-08 19:34:10,837 - INFO - Página 352/500 processada.
# 2024-04-08 19:34:12,007 - INFO - Página 353/500 processada.
# 2024-04-08 19:34:13,176 - INFO - Página 354/500 processada.
# 2024-04-08 19:34:14,404 - INFO - Página 355/500 processada.
# 2024-04-08 19:34:15,540 - INFO - Página 356/500 processada.
# 2024-04-08 19:34:17,129 - INFO - Página 357/500 processada.
# 2024-04-08 19:34:18,201 - INFO - Página 358/500 processada.
# 2024-04-08 19:34:19,941 - INFO - Página 359/500 processada.
# 2024-04-08 19:34:21,056 - INFO - Página 360/500 processada.
# 2024-04-08 19:34:22,305 - INFO - Página 361/500 processada.
# 2024-04-08 19:34:23,620 - INFO - Página 362/500 processada.
# 2024-04-08 19:34:24,939 - INFO - Página 363/500 processada.
# 2024-04-08 19:34:26,390 - INFO - Página 364/500 processada.
# 2024-04-08 19:34:27,486 - INFO - Página 365/500 processada.
# 2024-04-08 19:34:28,649 - INFO - Página 366/500 processada.
# 2024-04-08 19:34:29,862 - INFO - Página 367/500 processada.
# 2024-04-08 19:34:31,080 - INFO - Página 368/500 processada.
# 2024-04-08 19:34:32,539 - INFO - Página 369/500 processada.
# 2024-04-08 19:34:33,868 - INFO - Página 370/500 processada.
# 2024-04-08 19:34:34,883 - INFO - Página 371/500 processada.
# 2024-04-08 19:34:36,239 - INFO - Página 372/500 processada.
# 2024-04-08 19:34:37,439 - INFO - Página 373/500 processada.
# 2024-04-08 19:34:38,594 - INFO - Página 374/500 processada.
# 2024-04-08 19:34:39,759 - INFO - Página 375/500 processada.
# 2024-04-08 19:34:40,641 - INFO - Página 376/500 processada.
# 2024-04-08 19:34:41,741 - INFO - Página 377/500 processada.
# 2024-04-08 19:34:42,973 - INFO - Página 378/500 processada.
# 2024-04-08 19:34:44,209 - INFO - Página 379/500 processada.
# 2024-04-08 19:34:45,256 - INFO - Página 380/500 processada.
# 2024-04-08 19:34:46,349 - INFO - Página 381/500 processada.
# 2024-04-08 19:34:47,516 - INFO - Página 382/500 processada.
# 2024-04-08 19:34:48,920 - INFO - Página 383/500 processada.
# 2024-04-08 19:34:50,249 - INFO - Página 384/500 processada.
# 2024-04-08 19:34:51,369 - INFO - Página 385/500 processada.
# 2024-04-08 19:34:52,811 - INFO - Página 386/500 processada.
# 2024-04-08 19:34:53,906 - INFO - Página 387/500 processada.
# 2024-04-08 19:34:55,265 - INFO - Página 388/500 processada.
# 2024-04-08 19:34:56,538 - INFO - Página 389/500 processada.
# 2024-04-08 19:34:57,554 - INFO - Página 390/500 processada.
# 2024-04-08 19:34:58,669 - INFO - Página 391/500 processada.
# 2024-04-08 19:34:59,869 - INFO - Página 392/500 processada.
# 2024-04-08 19:35:01,091 - INFO - Página 393/500 processada.
# 2024-04-08 19:35:02,660 - INFO - Página 394/500 processada.
# 2024-04-08 19:35:03,770 - INFO - Página 395/500 processada.
# 2024-04-08 19:35:05,034 - INFO - Página 396/500 processada.
# 2024-04-08 19:35:06,140 - INFO - Página 397/500 processada.
# 2024-04-08 19:35:07,551 - INFO - Página 398/500 processada.
# 2024-04-08 19:35:08,589 - INFO - Página 399/500 processada.
# 2024-04-08 19:35:09,811 - INFO - Página 400/500 processada.
# 2024-04-08 19:35:11,078 - INFO - Página 401/500 processada.
# 2024-04-08 19:35:12,160 - INFO - Página 402/500 processada.
# 2024-04-08 19:35:13,311 - INFO - Página 403/500 processada.
# 2024-04-08 19:35:14,320 - INFO - Página 404/500 processada.
# 2024-04-08 19:35:15,343 - INFO - Página 405/500 processada.
# 2024-04-08 19:35:16,262 - INFO - Página 406/500 processada.
# 2024-04-08 19:35:17,371 - INFO - Página 407/500 processada.
# 2024-04-08 19:35:18,293 - INFO - Página 408/500 processada.
# 2024-04-08 19:35:19,426 - INFO - Página 409/500 processada.
# 2024-04-08 19:35:20,548 - INFO - Página 410/500 processada.
# 2024-04-08 19:35:21,585 - INFO - Página 411/500 processada.
# 2024-04-08 19:35:22,938 - INFO - Página 412/500 processada.
# 2024-04-08 19:35:24,067 - INFO - Página 413/500 processada.
# 2024-04-08 19:35:25,074 - INFO - Página 414/500 processada.
# 2024-04-08 19:35:26,202 - INFO - Página 415/500 processada.
# 2024-04-08 19:35:27,221 - INFO - Página 416/500 processada.
# 2024-04-08 19:35:28,253 - INFO - Página 417/500 processada.
# 2024-04-08 19:35:29,370 - INFO - Página 418/500 processada.
# 2024-04-08 19:35:30,508 - INFO - Página 419/500 processada.
# 2024-04-08 19:35:31,709 - INFO - Página 420/500 processada.
# 2024-04-08 19:35:32,859 - INFO - Página 421/500 processada.
# 2024-04-08 19:35:34,106 - INFO - Página 422/500 processada.
# 2024-04-08 19:35:35,252 - INFO - Página 423/500 processada.
# 2024-04-08 19:35:36,215 - INFO - Página 424/500 processada.
# 2024-04-08 19:35:37,271 - INFO - Página 425/500 processada.
# 2024-04-08 19:35:39,416 - INFO - Página 426/500 processada.
# 2024-04-08 19:35:40,523 - INFO - Página 427/500 processada.
# 2024-04-08 19:35:41,652 - INFO - Página 428/500 processada.
# 2024-04-08 19:35:42,772 - INFO - Página 429/500 processada.
# 2024-04-08 19:35:44,132 - INFO - Página 430/500 processada.
# 2024-04-08 19:35:45,280 - INFO - Página 431/500 processada.
# 2024-04-08 19:35:46,370 - INFO - Página 432/500 processada.
# 2024-04-08 19:35:47,507 - INFO - Página 433/500 processada.
# 2024-04-08 19:35:48,639 - INFO - Página 434/500 processada.
# 2024-04-08 19:35:49,795 - INFO - Página 435/500 processada.
# 2024-04-08 19:35:50,889 - INFO - Página 436/500 processada.
# 2024-04-08 19:35:51,915 - INFO - Página 437/500 processada.
# 2024-04-08 19:35:53,124 - INFO - Página 438/500 processada.
# 2024-04-08 19:35:54,255 - INFO - Página 439/500 processada.
# 2024-04-08 19:35:55,276 - INFO - Página 440/500 processada.
# 2024-04-08 19:35:56,299 - INFO - Página 441/500 processada.
# 2024-04-08 19:35:57,446 - INFO - Página 442/500 processada.
# 2024-04-08 19:35:58,439 - INFO - Página 443/500 processada.
# 2024-04-08 19:35:59,512 - INFO - Página 444/500 processada.
# 2024-04-08 19:36:00,621 - INFO - Página 445/500 processada.
# 2024-04-08 19:36:01,648 - INFO - Página 446/500 processada.
# 2024-04-08 19:36:02,770 - INFO - Página 447/500 processada.
# 2024-04-08 19:36:03,783 - INFO - Página 448/500 processada.
# 2024-04-08 19:36:04,886 - INFO - Página 449/500 processada.
# 2024-04-08 19:36:05,924 - INFO - Página 450/500 processada.
# 2024-04-08 19:36:06,938 - INFO - Página 451/500 processada.
# 2024-04-08 19:36:08,073 - INFO - Página 452/500 processada.
# 2024-04-08 19:36:09,303 - INFO - Página 453/500 processada.
# 2024-04-08 19:36:10,317 - INFO - Página 454/500 processada.
# 2024-04-08 19:36:11,325 - INFO - Página 455/500 processada.
# 2024-04-08 19:36:12,589 - INFO - Página 456/500 processada.
# 2024-04-08 19:36:13,812 - INFO - Página 457/500 processada.
# 2024-04-08 19:36:14,739 - INFO - Página 458/500 processada.
# 2024-04-08 19:36:15,705 - INFO - Página 459/500 processada.
# 2024-04-08 19:36:16,783 - INFO - Página 460/500 processada.
# 2024-04-08 19:36:17,890 - INFO - Página 461/500 processada.
# 2024-04-08 19:36:19,009 - INFO - Página 462/500 processada.
# 2024-04-08 19:36:20,070 - INFO - Página 463/500 processada.
# 2024-04-08 19:36:21,070 - INFO - Página 464/500 processada.
# 2024-04-08 19:36:22,106 - INFO - Página 465/500 processada.
# 2024-04-08 19:36:23,223 - INFO - Página 466/500 processada.
# 2024-04-08 19:36:24,315 - INFO - Página 467/500 processada.
# 2024-04-08 19:36:25,386 - INFO - Página 468/500 processada.
# 2024-04-08 19:36:26,506 - INFO - Página 469/500 processada.
# 2024-04-08 19:36:27,654 - INFO - Página 470/500 processada.
# 2024-04-08 19:36:28,757 - INFO - Página 471/500 processada.
# 2024-04-08 19:36:29,883 - INFO - Página 472/500 processada.
# 2024-04-08 19:36:30,892 - INFO - Página 473/500 processada.
# 2024-04-08 19:36:31,925 - INFO - Página 474/500 processada.
# 2024-04-08 19:36:32,965 - INFO - Página 475/500 processada.
# 2024-04-08 19:36:34,099 - INFO - Página 476/500 processada.
# 2024-04-08 19:36:35,103 - INFO - Página 477/500 processada.
# 2024-04-08 19:36:36,134 - INFO - Página 478/500 processada.
# 2024-04-08 19:36:37,135 - INFO - Página 479/500 processada.
# 2024-04-08 19:36:38,323 - INFO - Página 480/500 processada.
# 2024-04-08 19:36:39,546 - INFO - Página 481/500 processada.
# 2024-04-08 19:36:40,702 - INFO - Página 482/500 processada.
# 2024-04-08 19:36:41,804 - INFO - Página 483/500 processada.
# 2024-04-08 19:36:42,964 - INFO - Página 484/500 processada.
# 2024-04-08 19:36:44,049 - INFO - Página 485/500 processada.
# 2024-04-08 19:36:45,058 - INFO - Página 486/500 processada.
# 2024-04-08 19:36:46,074 - INFO - Página 487/500 processada.
# 2024-04-08 19:36:47,089 - INFO - Página 488/500 processada.
# 2024-04-08 19:36:48,102 - INFO - Página 489/500 processada.
# 2024-04-08 19:36:49,309 - INFO - Página 490/500 processada.
# 2024-04-08 19:36:50,455 - INFO - Página 491/500 processada.
# 2024-04-08 19:36:51,452 - INFO - Página 492/500 processada.
# 2024-04-08 19:36:52,618 - INFO - Página 493/500 processada.
# 2024-04-08 19:36:53,653 - INFO - Página 494/500 processada.
# 2024-04-08 19:36:54,651 - INFO - Página 495/500 processada.
# 2024-04-08 19:36:55,665 - INFO - Página 496/500 processada.
# 2024-04-08 19:36:56,748 - INFO - Página 497/500 processada.
# 2024-04-08 19:36:57,856 - INFO - Página 498/500 processada.
# 2024-04-08 19:36:58,892 - INFO - Página 499/500 processada.
# 2024-04-08 19:36:59,951 - INFO - Página 500/500 processada.
# 2024-04-08 19:37:01,461 - INFO - Página 1/500 processada.
# 2024-04-08 19:37:02,190 - INFO - Página 2/500 processada.
# 2024-04-08 19:37:02,999 - INFO - Página 3/500 processada.
# 2024-04-08 19:37:03,937 - INFO - Página 4/500 processada.
# 2024-04-08 19:37:04,852 - INFO - Página 5/500 processada.
# 2024-04-08 19:37:05,707 - INFO - Página 6/500 processada.
# 2024-04-08 19:37:06,588 - INFO - Página 7/500 processada.
# 2024-04-08 19:37:07,519 - INFO - Página 8/500 processada.
# 2024-04-08 19:37:08,431 - INFO - Página 9/500 processada.
# 2024-04-08 19:37:09,258 - INFO - Página 10/500 processada.
# 2024-04-08 19:37:10,065 - INFO - Página 11/500 processada.
# 2024-04-08 19:37:10,735 - INFO - Página 12/500 processada.
# 2024-04-08 19:37:11,426 - INFO - Página 13/500 processada.
# 2024-04-08 19:37:12,121 - INFO - Página 14/500 processada.
# 2024-04-08 19:37:12,931 - INFO - Página 15/500 processada.
# 2024-04-08 19:37:13,650 - INFO - Página 16/500 processada.
# 2024-04-08 19:37:14,370 - INFO - Página 17/500 processada.
# 2024-04-08 19:37:15,188 - INFO - Página 18/500 processada.
# 2024-04-08 19:37:16,009 - INFO - Página 19/500 processada.
# 2024-04-08 19:37:16,732 - INFO - Página 20/500 processada.
# 2024-04-08 19:37:17,554 - INFO - Página 21/500 processada.
# 2024-04-08 19:37:18,260 - INFO - Página 22/500 processada.
# 2024-04-08 19:37:19,081 - INFO - Página 23/500 processada.
# 2024-04-08 19:37:19,855 - INFO - Página 24/500 processada.
# 2024-04-08 19:37:20,564 - INFO - Página 25/500 processada.
# 2024-04-08 19:37:21,330 - INFO - Página 26/500 processada.
# 2024-04-08 19:37:22,263 - INFO - Página 27/500 processada.
# 2024-04-08 19:37:23,070 - INFO - Página 28/500 processada.
# 2024-04-08 19:37:23,787 - INFO - Página 29/500 processada.
# 2024-04-08 19:37:24,708 - INFO - Página 30/500 processada.
# 2024-04-08 19:37:25,432 - INFO - Página 31/500 processada.
# 2024-04-08 19:37:26,269 - INFO - Página 32/500 processada.
# 2024-04-08 19:37:26,972 - INFO - Página 33/500 processada.
# 2024-04-08 19:37:27,797 - INFO - Página 34/500 processada.
# 2024-04-08 19:37:28,530 - INFO - Página 35/500 processada.
# 2024-04-08 19:37:29,331 - INFO - Página 36/500 processada.
# 2024-04-08 19:37:30,134 - INFO - Página 37/500 processada.
# 2024-04-08 19:37:30,964 - INFO - Página 38/500 processada.
# 2024-04-08 19:37:31,651 - INFO - Página 39/500 processada.
# 2024-04-08 19:37:32,398 - INFO - Página 40/500 processada.
# 2024-04-08 19:37:33,215 - INFO - Página 41/500 processada.
# 2024-04-08 19:37:33,928 - INFO - Página 42/500 processada.
# 2024-04-08 19:37:34,653 - INFO - Página 43/500 processada.
# 2024-04-08 19:37:35,302 - INFO - Página 44/500 processada.
# 2024-04-08 19:37:35,977 - INFO - Página 45/500 processada.
# 2024-04-08 19:37:36,802 - INFO - Página 46/500 processada.
# 2024-04-08 19:37:37,497 - INFO - Página 47/500 processada.
# 2024-04-08 19:37:38,170 - INFO - Página 48/500 processada.
# 2024-04-08 19:37:38,958 - INFO - Página 49/500 processada.
# 2024-04-08 19:37:39,701 - INFO - Página 50/500 processada.
# 2024-04-08 19:37:40,367 - INFO - Página 51/500 processada.
# 2024-04-08 19:37:41,100 - INFO - Página 52/500 processada.
# 2024-04-08 19:37:41,915 - INFO - Página 53/500 processada.
# 2024-04-08 19:37:42,574 - INFO - Página 54/500 processada.
# 2024-04-08 19:37:43,353 - INFO - Página 55/500 processada.
# 2024-04-08 19:37:44,069 - INFO - Página 56/500 processada.
# 2024-04-08 19:37:44,784 - INFO - Página 57/500 processada.
# 2024-04-08 19:37:45,603 - INFO - Página 58/500 processada.
# 2024-04-08 19:37:46,319 - INFO - Página 59/500 processada.
# 2024-04-08 19:37:47,056 - INFO - Página 60/500 processada.
# 2024-04-08 19:37:47,956 - INFO - Página 61/500 processada.
# 2024-04-08 19:37:48,775 - INFO - Página 62/500 processada.
# 2024-04-08 19:37:49,632 - INFO - Página 63/500 processada.
# 2024-04-08 19:37:50,321 - INFO - Página 64/500 processada.
# 2024-04-08 19:37:51,100 - INFO - Página 65/500 processada.
# 2024-04-08 19:37:51,775 - INFO - Página 66/500 processada.
# 2024-04-08 19:37:52,568 - INFO - Página 67/500 processada.
# 2024-04-08 19:37:53,243 - INFO - Página 68/500 processada.
# 2024-04-08 19:37:53,892 - INFO - Página 69/500 processada.
# 2024-04-08 19:37:54,713 - INFO - Página 70/500 processada.
# 2024-04-08 19:37:55,538 - INFO - Página 71/500 processada.
# 2024-04-08 19:37:56,203 - INFO - Página 72/500 processada.
# 2024-04-08 19:37:56,945 - INFO - Página 73/500 processada.
# 2024-04-08 19:37:57,696 - INFO - Página 74/500 processada.
# 2024-04-08 19:37:58,369 - INFO - Página 75/500 processada.
# 2024-04-08 19:37:59,229 - INFO - Página 76/500 processada.
# 2024-04-08 19:38:00,053 - INFO - Página 77/500 processada.
# 2024-04-08 19:38:00,873 - INFO - Página 78/500 processada.
# 2024-04-08 19:38:01,720 - INFO - Página 79/500 processada.
# 2024-04-08 19:38:02,487 - INFO - Página 80/500 processada.
# 2024-04-08 19:38:03,315 - INFO - Página 81/500 processada.
# 2024-04-08 19:38:04,251 - INFO - Página 82/500 processada.
# 2024-04-08 19:38:04,998 - INFO - Página 83/500 processada.
# 2024-04-08 19:38:05,879 - INFO - Página 84/500 processada.
# 2024-04-08 19:38:06,799 - INFO - Página 85/500 processada.
# 2024-04-08 19:38:07,622 - INFO - Página 86/500 processada.
# 2024-04-08 19:38:08,650 - INFO - Página 87/500 processada.
# 2024-04-08 19:38:09,664 - INFO - Página 88/500 processada.
# 2024-04-08 19:38:10,471 - INFO - Página 89/500 processada.
# 2024-04-08 19:38:11,213 - INFO - Página 90/500 processada.
# 2024-04-08 19:38:12,030 - INFO - Página 91/500 processada.
# 2024-04-08 19:38:12,850 - INFO - Página 92/500 processada.
# 2024-04-08 19:38:13,768 - INFO - Página 93/500 processada.
# 2024-04-08 19:38:14,501 - INFO - Página 94/500 processada.
# 2024-04-08 19:38:15,375 - INFO - Página 95/500 processada.
# 2024-04-08 19:38:16,075 - INFO - Página 96/500 processada.
# 2024-04-08 19:38:16,842 - INFO - Página 97/500 processada.
# 2024-04-08 19:38:17,645 - INFO - Página 98/500 processada.
# 2024-04-08 19:38:18,359 - INFO - Página 99/500 processada.
# 2024-04-08 19:38:19,268 - INFO - Página 100/500 processada.
# 2024-04-08 19:38:20,089 - INFO - Página 101/500 processada.
# 2024-04-08 19:38:20,826 - INFO - Página 102/500 processada.
# 2024-04-08 19:38:21,629 - INFO - Página 103/500 processada.
# 2024-04-08 19:38:22,581 - INFO - Página 104/500 processada.
# 2024-04-08 19:38:23,598 - INFO - Página 105/500 processada.
# 2024-04-08 19:38:24,620 - INFO - Página 106/500 processada.
# 2024-04-08 19:38:25,540 - INFO - Página 107/500 processada.
# 2024-04-08 19:38:26,254 - INFO - Página 108/500 processada.
# 2024-04-08 19:38:26,983 - INFO - Página 109/500 processada.
# 2024-04-08 19:38:27,664 - INFO - Página 110/500 processada.
# 2024-04-08 19:38:28,504 - INFO - Página 111/500 processada.
# 2024-04-08 19:38:29,344 - INFO - Página 112/500 processada.
# 2024-04-08 19:38:30,144 - INFO - Página 113/500 processada.
# 2024-04-08 19:38:30,966 - INFO - Página 114/500 processada.
# 2024-04-08 19:38:31,788 - INFO - Página 115/500 processada.
# 2024-04-08 19:38:32,597 - INFO - Página 116/500 processada.
# 2024-04-08 19:38:33,515 - INFO - Página 117/500 processada.
# 2024-04-08 19:38:34,301 - INFO - Página 118/500 processada.
# 2024-04-08 19:38:35,166 - INFO - Página 119/500 processada.
# 2024-04-08 19:38:35,988 - INFO - Página 120/500 processada.
# 2024-04-08 19:38:36,766 - INFO - Página 121/500 processada.
# 2024-04-08 19:38:37,629 - INFO - Página 122/500 processada.
# 2024-04-08 19:38:38,646 - INFO - Página 123/500 processada.
# 2024-04-08 19:38:39,675 - INFO - Página 124/500 processada.
# 2024-04-08 19:38:40,796 - INFO - Página 125/500 processada.
# 2024-04-08 19:38:41,721 - INFO - Página 126/500 processada.
# 2024-04-08 19:38:42,533 - INFO - Página 127/500 processada.
# 2024-04-08 19:38:43,368 - INFO - Página 128/500 processada.
# 2024-04-08 19:38:44,285 - INFO - Página 129/500 processada.
# 2024-04-08 19:38:45,317 - INFO - Página 130/500 processada.
# 2024-04-08 19:38:46,124 - INFO - Página 131/500 processada.
# 2024-04-08 19:38:46,888 - INFO - Página 132/500 processada.
# 2024-04-08 19:38:47,782 - INFO - Página 133/500 processada.
# 2024-04-08 19:38:48,692 - INFO - Página 134/500 processada.
# 2024-04-08 19:38:49,512 - INFO - Página 135/500 processada.
# 2024-04-08 19:38:50,431 - INFO - Página 136/500 processada.
# 2024-04-08 19:38:51,448 - INFO - Página 137/500 processada.
# 2024-04-08 19:38:52,376 - INFO - Página 138/500 processada.
# 2024-04-08 19:38:53,116 - INFO - Página 139/500 processada.
# 2024-04-08 19:38:54,122 - INFO - Página 140/500 processada.
# 2024-04-08 19:38:55,040 - INFO - Página 141/500 processada.
# 2024-04-08 19:38:55,846 - INFO - Página 142/500 processada.
# 2024-04-08 19:38:56,698 - INFO - Página 143/500 processada.
# 2024-04-08 19:38:57,588 - INFO - Página 144/500 processada.
# 2024-04-08 19:38:58,415 - INFO - Página 145/500 processada.
# 2024-04-08 19:38:59,241 - INFO - Página 146/500 processada.
# 2024-04-08 19:39:00,037 - INFO - Página 147/500 processada.
# 2024-04-08 19:39:00,877 - INFO - Página 148/500 processada.
# 2024-04-08 19:39:01,751 - INFO - Página 149/500 processada.
# 2024-04-08 19:39:02,552 - INFO - Página 150/500 processada.
# 2024-04-08 19:39:03,278 - INFO - Página 151/500 processada.
# 2024-04-08 19:39:04,151 - INFO - Página 152/500 processada.
# 2024-04-08 19:39:04,902 - INFO - Página 153/500 processada.
# 2024-04-08 19:39:05,752 - INFO - Página 154/500 processada.
# 2024-04-08 19:39:06,475 - INFO - Página 155/500 processada.
# 2024-04-08 19:39:07,317 - INFO - Página 156/500 processada.
# 2024-04-08 19:39:08,153 - INFO - Página 157/500 processada.
# 2024-04-08 19:39:08,953 - INFO - Página 158/500 processada.
# 2024-04-08 19:39:09,884 - INFO - Página 159/500 processada.
# 2024-04-08 19:39:10,567 - INFO - Página 160/500 processada.
# 2024-04-08 19:39:11,423 - INFO - Página 161/500 processada.
# 2024-04-08 19:39:12,223 - INFO - Página 162/500 processada.
# 2024-04-08 19:39:13,032 - INFO - Página 163/500 processada.
# 2024-04-08 19:39:13,969 - INFO - Página 164/500 processada.
# 2024-04-08 19:39:14,793 - INFO - Página 165/500 processada.
# 2024-04-08 19:39:15,831 - INFO - Página 166/500 processada.
# 2024-04-08 19:39:16,750 - INFO - Página 167/500 processada.
# 2024-04-08 19:39:17,644 - INFO - Página 168/500 processada.
# 2024-04-08 19:39:18,558 - INFO - Página 169/500 processada.
# 2024-04-08 19:39:19,513 - INFO - Página 170/500 processada.
# 2024-04-08 19:39:20,321 - INFO - Página 171/500 processada.
# 2024-04-08 19:39:21,270 - INFO - Página 172/500 processada.
# 2024-04-08 19:39:22,024 - INFO - Página 173/500 processada.
# 2024-04-08 19:39:22,881 - INFO - Página 174/500 processada.
# 2024-04-08 19:39:23,807 - INFO - Página 175/500 processada.
# 2024-04-08 19:39:24,631 - INFO - Página 176/500 processada.
# 2024-04-08 19:39:25,354 - INFO - Página 177/500 processada.
# 2024-04-08 19:39:26,265 - INFO - Página 178/500 processada.
# 2024-04-08 19:39:27,186 - INFO - Página 179/500 processada.
# 2024-04-08 19:39:27,925 - INFO - Página 180/500 processada.
# 2024-04-08 19:39:28,658 - INFO - Página 181/500 processada.
# 2024-04-08 19:39:29,748 - INFO - Página 182/500 processada.
# 2024-04-08 19:39:30,875 - INFO - Página 183/500 processada.
# 2024-04-08 19:39:31,898 - INFO - Página 184/500 processada.
# 2024-04-08 19:39:32,725 - INFO - Página 185/500 processada.
# 2024-04-08 19:39:33,735 - INFO - Página 186/500 processada.
# 2024-04-08 19:39:34,762 - INFO - Página 187/500 processada.
# 2024-04-08 19:39:35,800 - INFO - Página 188/500 processada.
# 2024-04-08 19:39:37,017 - INFO - Página 189/500 processada.
# 2024-04-08 19:39:37,856 - INFO - Página 190/500 processada.
# 2024-04-08 19:39:39,083 - INFO - Página 191/500 processada.
# 2024-04-08 19:39:40,292 - INFO - Página 192/500 processada.
# 2024-04-08 19:39:41,102 - INFO - Página 193/500 processada.
# 2024-04-08 19:39:42,050 - INFO - Página 194/500 processada.
# 2024-04-08 19:39:42,853 - INFO - Página 195/500 processada.
# 2024-04-08 19:39:43,674 - INFO - Página 196/500 processada.
# 2024-04-08 19:39:44,497 - INFO - Página 197/500 processada.
# 2024-04-08 19:39:45,304 - INFO - Página 198/500 processada.
# 2024-04-08 19:39:46,224 - INFO - Página 199/500 processada.
# 2024-04-08 19:39:46,929 - INFO - Página 200/500 processada.
# 2024-04-08 19:39:47,762 - INFO - Página 201/500 processada.
# 2024-04-08 19:39:48,584 - INFO - Página 202/500 processada.
# 2024-04-08 19:39:49,404 - INFO - Página 203/500 processada.
# 2024-04-08 19:39:50,320 - INFO - Página 204/500 processada.
# 2024-04-08 19:39:51,148 - INFO - Página 205/500 processada.
# 2024-04-08 19:39:52,247 - INFO - Página 206/500 processada.
# 2024-04-08 19:39:53,181 - INFO - Página 207/500 processada.
# 2024-04-08 19:39:54,114 - INFO - Página 208/500 processada.
# 2024-04-08 19:39:54,942 - INFO - Página 209/500 processada.
# 2024-04-08 19:39:55,767 - INFO - Página 210/500 processada.
# 2024-04-08 19:39:56,517 - INFO - Página 211/500 processada.
# 2024-04-08 19:39:57,605 - INFO - Página 212/500 processada.
# 2024-04-08 19:39:58,521 - INFO - Página 213/500 processada.
# 2024-04-08 19:39:59,444 - INFO - Página 214/500 processada.
# 2024-04-08 19:40:00,261 - INFO - Página 215/500 processada.
# 2024-04-08 19:40:01,265 - INFO - Página 216/500 processada.
# 2024-04-08 19:40:02,198 - INFO - Página 217/500 processada.
# 2024-04-08 19:40:02,996 - INFO - Página 218/500 processada.
# 2024-04-08 19:40:03,845 - INFO - Página 219/500 processada.
# 2024-04-08 19:40:04,652 - INFO - Página 220/500 processada.
# 2024-04-08 19:40:05,491 - INFO - Página 221/500 processada.
# 2024-04-08 19:40:06,602 - INFO - Página 222/500 processada.
# 2024-04-08 19:40:07,331 - INFO - Página 223/500 processada.
# 2024-04-08 19:40:08,314 - INFO - Página 224/500 processada.
# 2024-04-08 19:40:09,530 - INFO - Página 225/500 processada.
# 2024-04-08 19:40:10,452 - INFO - Página 226/500 processada.
# 2024-04-08 19:40:11,626 - INFO - Página 227/500 processada.
# 2024-04-08 19:40:12,905 - INFO - Página 228/500 processada.
# 2024-04-08 19:40:13,833 - INFO - Página 229/500 processada.
# 2024-04-08 19:40:14,798 - INFO - Página 230/500 processada.
# 2024-04-08 19:40:15,626 - INFO - Página 231/500 processada.
# 2024-04-08 19:40:16,545 - INFO - Página 232/500 processada.
# 2024-04-08 19:40:17,464 - INFO - Página 233/500 processada.
# 2024-04-08 19:40:18,293 - INFO - Página 234/500 processada.
# 2024-04-08 19:40:19,203 - INFO - Página 235/500 processada.
# 2024-04-08 19:40:20,121 - INFO - Página 236/500 processada.
# 2024-04-08 19:40:21,044 - INFO - Página 237/500 processada.
# 2024-04-08 19:40:21,868 - INFO - Página 238/500 processada.
# 2024-04-08 19:40:22,669 - INFO - Página 239/500 processada.
# 2024-04-08 19:40:23,512 - INFO - Página 240/500 processada.
# 2024-04-08 19:40:24,430 - INFO - Página 241/500 processada.
# 2024-04-08 19:40:25,249 - INFO - Página 242/500 processada.
# 2024-04-08 19:40:26,067 - INFO - Página 243/500 processada.
# 2024-04-08 19:40:26,982 - INFO - Página 244/500 processada.
# 2024-04-08 19:40:28,011 - INFO - Página 245/500 processada.
# 2024-04-08 19:40:28,934 - INFO - Página 246/500 processada.
# 2024-04-08 19:40:30,061 - INFO - Página 247/500 processada.
# 2024-04-08 19:40:30,980 - INFO - Página 248/500 processada.
# 2024-04-08 19:40:31,750 - INFO - Página 249/500 processada.
# 2024-04-08 19:40:32,557 - INFO - Página 250/500 processada.
# 2024-04-08 19:40:33,546 - INFO - Página 251/500 processada.
# 2024-04-08 19:40:34,364 - INFO - Página 252/500 processada.
# 2024-04-08 19:40:35,200 - INFO - Página 253/500 processada.
# 2024-04-08 19:40:36,097 - INFO - Página 254/500 processada.
# 2024-04-08 19:40:36,919 - INFO - Página 255/500 processada.
# 2024-04-08 19:40:37,702 - INFO - Página 256/500 processada.
# 2024-04-08 19:40:38,660 - INFO - Página 257/500 processada.
# 2024-04-08 19:40:39,487 - INFO - Página 258/500 processada.
# 2024-04-08 19:40:40,500 - INFO - Página 259/500 processada.
# 2024-04-08 19:40:41,322 - INFO - Página 260/500 processada.
# 2024-04-08 19:40:42,249 - INFO - Página 261/500 processada.
# 2024-04-08 19:40:43,070 - INFO - Página 262/500 processada.
# 2024-04-08 19:40:43,989 - INFO - Página 263/500 processada.
# 2024-04-08 19:40:45,191 - INFO - Página 264/500 processada.
# 2024-04-08 19:40:45,935 - INFO - Página 265/500 processada.
# 2024-04-08 19:40:46,855 - INFO - Página 266/500 processada.
# 2024-04-08 19:40:47,981 - INFO - Página 267/500 processada.
# 2024-04-08 19:40:48,997 - INFO - Página 268/500 processada.
# 2024-04-08 19:40:49,844 - INFO - Página 269/500 processada.
# 2024-04-08 19:40:50,751 - INFO - Página 270/500 processada.
# 2024-04-08 19:40:51,564 - INFO - Página 271/500 processada.
# 2024-04-08 19:40:52,520 - INFO - Página 272/500 processada.
# 2024-04-08 19:40:53,497 - INFO - Página 273/500 processada.
# 2024-04-08 19:40:54,535 - INFO - Página 274/500 processada.
# 2024-04-08 19:40:55,349 - INFO - Página 275/500 processada.
# 2024-04-08 19:40:56,269 - INFO - Página 276/500 processada.
# 2024-04-08 19:40:57,094 - INFO - Página 277/500 processada.
# 2024-04-08 19:40:58,016 - INFO - Página 278/500 processada.
# 2024-04-08 19:40:58,835 - INFO - Página 279/500 processada.
# 2024-04-08 19:40:59,965 - INFO - Página 280/500 processada.
# 2024-04-08 19:41:00,885 - INFO - Página 281/500 processada.
# 2024-04-08 19:41:01,688 - INFO - Página 282/500 processada.
# 2024-04-08 19:41:02,527 - INFO - Página 283/500 processada.
# 2024-04-08 19:41:03,435 - INFO - Página 284/500 processada.
# 2024-04-08 19:41:04,260 - INFO - Página 285/500 processada.
# 2024-04-08 19:41:05,285 - INFO - Página 286/500 processada.
# 2024-04-08 19:41:06,315 - INFO - Página 287/500 processada.
# 2024-04-08 19:41:07,230 - INFO - Página 288/500 processada.
# 2024-04-08 19:41:08,152 - INFO - Página 289/500 processada.
# 2024-04-08 19:41:08,969 - INFO - Página 290/500 processada.
# 2024-04-08 19:41:09,898 - INFO - Página 291/500 processada.
# 2024-04-08 19:41:10,707 - INFO - Página 292/500 processada.
# 2024-04-08 19:41:11,531 - INFO - Página 293/500 processada.
# 2024-04-08 19:41:12,556 - INFO - Página 294/500 processada.
# 2024-04-08 19:41:13,237 - INFO - Página 295/500 processada.
# 2024-04-08 19:41:14,193 - INFO - Página 296/500 processada.
# 2024-04-08 19:41:15,115 - INFO - Página 297/500 processada.
# 2024-04-08 19:41:15,932 - INFO - Página 298/500 processada.
# 2024-04-08 19:41:16,767 - INFO - Página 299/500 processada.
# 2024-04-08 19:41:17,667 - INFO - Página 300/500 processada.
# 2024-04-08 19:41:18,503 - INFO - Página 301/500 processada.
# 2024-04-08 19:41:19,418 - INFO - Página 302/500 processada.
# 2024-04-08 19:41:20,337 - INFO - Página 303/500 processada.
# 2024-04-08 19:41:21,275 - INFO - Página 304/500 processada.
# 2024-04-08 19:41:22,149 - INFO - Página 305/500 processada.
# 2024-04-08 19:41:23,098 - INFO - Página 306/500 processada.
# 2024-04-08 19:41:24,126 - INFO - Página 307/500 processada.
# 2024-04-08 19:41:25,154 - INFO - Página 308/500 processada.
# 2024-04-08 19:41:26,070 - INFO - Página 309/500 processada.
# 2024-04-08 19:41:27,002 - INFO - Página 310/500 processada.
# 2024-04-08 19:41:27,922 - INFO - Página 311/500 processada.
# 2024-04-08 19:41:28,732 - INFO - Página 312/500 processada.
# 2024-04-08 19:41:29,654 - INFO - Página 313/500 processada.
# 2024-04-08 19:41:30,583 - INFO - Página 314/500 processada.
# 2024-04-08 19:41:31,390 - INFO - Página 315/500 processada.
# 2024-04-08 19:41:32,315 - INFO - Página 316/500 processada.
# 2024-04-08 19:41:33,346 - INFO - Página 317/500 processada.
# 2024-04-08 19:41:34,155 - INFO - Página 318/500 processada.
# 2024-04-08 19:41:35,191 - INFO - Página 319/500 processada.
# 2024-04-08 19:41:36,011 - INFO - Página 320/500 processada.
# 2024-04-08 19:41:36,933 - INFO - Página 321/500 processada.
# 2024-04-08 19:41:37,953 - INFO - Página 322/500 processada.
# 2024-04-08 19:41:38,769 - INFO - Página 323/500 processada.
# 2024-04-08 19:41:39,601 - INFO - Página 324/500 processada.
# 2024-04-08 19:41:40,383 - INFO - Página 325/500 processada.
# 2024-04-08 19:41:41,260 - INFO - Página 326/500 processada.
# 2024-04-08 19:41:42,150 - INFO - Página 327/500 processada.
# 2024-04-08 19:41:42,937 - INFO - Página 328/500 processada.
# 2024-04-08 19:41:43,786 - INFO - Página 329/500 processada.
# 2024-04-08 19:41:44,597 - INFO - Página 330/500 processada.
# 2024-04-08 19:41:45,630 - INFO - Página 331/500 processada.
# 2024-04-08 19:41:46,548 - INFO - Página 332/500 processada.
# 2024-04-08 19:41:47,474 - INFO - Página 333/500 processada.
# 2024-04-08 19:41:48,294 - INFO - Página 334/500 processada.
# 2024-04-08 19:41:49,217 - INFO - Página 335/500 processada.
# 2024-04-08 19:41:50,051 - INFO - Página 336/500 processada.
# 2024-04-08 19:41:50,853 - INFO - Página 337/500 processada.
# 2024-04-08 19:41:51,666 - INFO - Página 338/500 processada.
# 2024-04-08 19:41:52,496 - INFO - Página 339/500 processada.
# 2024-04-08 19:41:53,420 - INFO - Página 340/500 processada.
# 2024-04-08 19:41:54,258 - INFO - Página 341/500 processada.
# 2024-04-08 19:41:55,266 - INFO - Página 342/500 processada.
# 2024-04-08 19:41:56,181 - INFO - Página 343/500 processada.
# 2024-04-08 19:41:57,093 - INFO - Página 344/500 processada.
# 2024-04-08 19:41:58,142 - INFO - Página 345/500 processada.
# 2024-04-08 19:41:58,949 - INFO - Página 346/500 processada.
# 2024-04-08 19:41:59,879 - INFO - Página 347/500 processada.
# 2024-04-08 19:42:00,688 - INFO - Página 348/500 processada.
# 2024-04-08 19:42:01,626 - INFO - Página 349/500 processada.
# 2024-04-08 19:42:02,403 - INFO - Página 350/500 processada.
# 2024-04-08 19:42:03,143 - INFO - Página 351/500 processada.
# 2024-04-08 19:42:04,064 - INFO - Página 352/500 processada.
# 2024-04-08 19:42:04,762 - INFO - Página 353/500 processada.
# 2024-04-08 19:42:05,707 - INFO - Página 354/500 processada.
# 2024-04-08 19:42:06,453 - INFO - Página 355/500 processada.
# 2024-04-08 19:42:07,248 - INFO - Página 356/500 processada.
# 2024-04-08 19:42:07,941 - INFO - Página 357/500 processada.
# 2024-04-08 19:42:08,778 - INFO - Página 358/500 processada.
# 2024-04-08 19:42:09,707 - INFO - Página 359/500 processada.
# 2024-04-08 19:42:10,616 - INFO - Página 360/500 processada.
# 2024-04-08 19:42:11,338 - INFO - Página 361/500 processada.
# 2024-04-08 19:42:12,009 - INFO - Página 362/500 processada.
# 2024-04-08 19:42:12,774 - INFO - Página 363/500 processada.
# 2024-04-08 19:42:13,459 - INFO - Página 364/500 processada.
# 2024-04-08 19:42:14,396 - INFO - Página 365/500 processada.
# 2024-04-08 19:42:15,329 - INFO - Página 366/500 processada.
# 2024-04-08 19:42:16,259 - INFO - Página 367/500 processada.
# 2024-04-08 19:42:16,988 - INFO - Página 368/500 processada.
# 2024-04-08 19:42:17,786 - INFO - Página 369/500 processada.
# 2024-04-08 19:42:18,614 - INFO - Página 370/500 processada.
# 2024-04-08 19:42:19,539 - INFO - Página 371/500 processada.
# 2024-04-08 19:42:20,450 - INFO - Página 372/500 processada.
# 2024-04-08 19:42:21,127 - INFO - Página 373/500 processada.
# 2024-04-08 19:42:21,986 - INFO - Página 374/500 processada.
# 2024-04-08 19:42:22,717 - INFO - Página 375/500 processada.
# 2024-04-08 19:42:23,518 - INFO - Página 376/500 processada.
# 2024-04-08 19:42:24,542 - INFO - Página 377/500 processada.
# 2024-04-08 19:42:25,263 - INFO - Página 378/500 processada.
# 2024-04-08 19:42:25,967 - INFO - Página 379/500 processada.
# 2024-04-08 19:42:26,792 - INFO - Página 380/500 processada.
# 2024-04-08 19:42:27,510 - INFO - Página 381/500 processada.
# 2024-04-08 19:42:28,331 - INFO - Página 382/500 processada.
# 2024-04-08 19:42:29,262 - INFO - Página 383/500 processada.
# 2024-04-08 19:42:30,387 - INFO - Página 384/500 processada.
# 2024-04-08 19:42:31,294 - INFO - Página 385/500 processada.
# 2024-04-08 19:42:32,227 - INFO - Página 386/500 processada.
# 2024-04-08 19:42:33,117 - INFO - Página 387/500 processada.
# 2024-04-08 19:42:34,063 - INFO - Página 388/500 processada.
# 2024-04-08 19:42:34,997 - INFO - Página 389/500 processada.
# 2024-04-08 19:42:36,008 - INFO - Página 390/500 processada.
# 2024-04-08 19:42:36,938 - INFO - Página 391/500 processada.
# 2024-04-08 19:42:37,761 - INFO - Página 392/500 processada.
# 2024-04-08 19:42:38,578 - INFO - Página 393/500 processada.
# 2024-04-08 19:42:39,712 - INFO - Página 394/500 processada.
# 2024-04-08 19:42:40,504 - INFO - Página 395/500 processada.
# 2024-04-08 19:42:41,437 - INFO - Página 396/500 processada.
# 2024-04-08 19:42:42,207 - INFO - Página 397/500 processada.
# 2024-04-08 19:42:43,193 - INFO - Página 398/500 processada.
# 2024-04-08 19:42:44,204 - INFO - Página 399/500 processada.
# 2024-04-08 19:42:45,136 - INFO - Página 400/500 processada.
# 2024-04-08 19:42:45,946 - INFO - Página 401/500 processada.
# 2024-04-08 19:42:46,880 - INFO - Página 402/500 processada.
# 2024-04-08 19:42:47,691 - INFO - Página 403/500 processada.
# 2024-04-08 19:42:48,510 - INFO - Página 404/500 processada.
# 2024-04-08 19:42:49,638 - INFO - Página 405/500 processada.
# 2024-04-08 19:42:50,758 - INFO - Página 406/500 processada.
# 2024-04-08 19:42:51,796 - INFO - Página 407/500 processada.
# 2024-04-08 19:42:52,703 - INFO - Página 408/500 processada.
# 2024-04-08 19:42:53,618 - INFO - Página 409/500 processada.
# 2024-04-08 19:42:54,652 - INFO - Página 410/500 processada.
# 2024-04-08 19:42:55,584 - INFO - Página 411/500 processada.
# 2024-04-08 19:42:56,493 - INFO - Página 412/500 processada.
# 2024-04-08 19:42:57,426 - INFO - Página 413/500 processada.
# 2024-04-08 19:42:58,344 - INFO - Página 414/500 processada.
# 2024-04-08 19:42:59,148 - INFO - Página 415/500 processada.
# 2024-04-08 19:43:00,081 - INFO - Página 416/500 processada.
# 2024-04-08 19:43:00,993 - INFO - Página 417/500 processada.
# 2024-04-08 19:43:01,910 - INFO - Página 418/500 processada.
# 2024-04-08 19:43:02,746 - INFO - Página 419/500 processada.
# 2024-04-08 19:43:03,625 - INFO - Página 420/500 processada.
# 2024-04-08 19:43:04,479 - INFO - Página 421/500 processada.
# 2024-04-08 19:43:05,298 - INFO - Página 422/500 processada.
# 2024-04-08 19:43:06,115 - INFO - Página 423/500 processada.
# 2024-04-08 19:43:07,137 - INFO - Página 424/500 processada.
# 2024-04-08 19:43:08,068 - INFO - Página 425/500 processada.
# 2024-04-08 19:43:08,986 - INFO - Página 426/500 processada.
# 2024-04-08 19:43:10,114 - INFO - Página 427/500 processada.
# 2024-04-08 19:43:11,032 - INFO - Página 428/500 processada.
# 2024-04-08 19:43:11,961 - INFO - Página 429/500 processada.
# 2024-04-08 19:43:12,878 - INFO - Página 430/500 processada.
# 2024-04-08 19:43:13,793 - INFO - Página 431/500 processada.
# 2024-04-08 19:43:14,712 - INFO - Página 432/500 processada.
# 2024-04-08 19:43:15,542 - INFO - Página 433/500 processada.
# 2024-04-08 19:43:16,298 - INFO - Página 434/500 processada.
# 2024-04-08 19:43:17,277 - INFO - Página 435/500 processada.
# 2024-04-08 19:43:18,092 - INFO - Página 436/500 processada.
# 2024-04-08 19:43:19,025 - INFO - Página 437/500 processada.
# 2024-04-08 19:43:20,251 - INFO - Página 438/500 processada.
# 2024-04-08 19:43:21,065 - INFO - Página 439/500 processada.
# 2024-04-08 19:43:22,084 - INFO - Página 440/500 processada.
# 2024-04-08 19:43:22,904 - INFO - Página 441/500 processada.
# 2024-04-08 19:43:23,729 - INFO - Página 442/500 processada.
# 2024-04-08 19:43:24,652 - INFO - Página 443/500 processada.
# 2024-04-08 19:43:25,571 - INFO - Página 444/500 processada.
# 2024-04-08 19:43:26,702 - INFO - Página 445/500 processada.
# 2024-04-08 19:43:27,719 - INFO - Página 446/500 processada.
# 2024-04-08 19:43:28,749 - INFO - Página 447/500 processada.
# 2024-04-08 19:43:29,668 - INFO - Página 448/500 processada.
# 2024-04-08 19:43:30,592 - INFO - Página 449/500 processada.
# 2024-04-08 19:43:31,404 - INFO - Página 450/500 processada.
# 2024-04-08 19:43:32,426 - INFO - Página 451/500 processada.
# 2024-04-08 19:43:33,458 - INFO - Página 452/500 processada.
# 2024-04-08 19:43:34,574 - INFO - Página 453/500 processada.
# 2024-04-08 19:43:35,443 - INFO - Página 454/500 processada.
# 2024-04-08 19:43:36,432 - INFO - Página 455/500 processada.
# 2024-04-08 19:43:37,351 - INFO - Página 456/500 processada.
# 2024-04-08 19:43:38,271 - INFO - Página 457/500 processada.
# 2024-04-08 19:43:39,089 - INFO - Página 458/500 processada.
# 2024-04-08 19:43:40,124 - INFO - Página 459/500 processada.
# 2024-04-08 19:43:40,930 - INFO - Página 460/500 processada.
# 2024-04-08 19:43:41,764 - INFO - Página 461/500 processada.
# 2024-04-08 19:43:42,681 - INFO - Página 462/500 processada.
# 2024-04-08 19:43:43,581 - INFO - Página 463/500 processada.
# 2024-04-08 19:43:44,511 - INFO - Página 464/500 processada.
# 2024-04-08 19:43:45,542 - INFO - Página 465/500 processada.
# 2024-04-08 19:43:46,565 - INFO - Página 466/500 processada.
# 2024-04-08 19:43:47,908 - INFO - Página 467/500 processada.
# 2024-04-08 19:43:48,823 - INFO - Página 468/500 processada.
# 2024-04-08 19:43:49,634 - INFO - Página 469/500 processada.
# 2024-04-08 19:43:50,450 - INFO - Página 470/500 processada.
# 2024-04-08 19:43:51,582 - INFO - Página 471/500 processada.
# 2024-04-08 19:43:52,609 - INFO - Página 472/500 processada.
# 2024-04-08 19:43:53,458 - INFO - Página 473/500 processada.
# 2024-04-08 19:43:54,349 - INFO - Página 474/500 processada.
# 2024-04-08 19:43:55,268 - INFO - Página 475/500 processada.
# 2024-04-08 19:43:56,198 - INFO - Página 476/500 processada.
# 2024-04-08 19:43:57,108 - INFO - Página 477/500 processada.
# 2024-04-08 19:43:58,000 - INFO - Página 478/500 processada.
# 2024-04-08 19:43:58,751 - INFO - Página 479/500 processada.
# 2024-04-08 19:43:59,780 - INFO - Página 480/500 processada.
# 2024-04-08 19:44:00,791 - INFO - Página 481/500 processada.
# 2024-04-08 19:44:01,681 - INFO - Página 482/500 processada.
# 2024-04-08 19:44:02,643 - INFO - Página 483/500 processada.
# 2024-04-08 19:44:03,481 - INFO - Página 484/500 processada.
# 2024-04-08 19:44:04,294 - INFO - Página 485/500 processada.
# 2024-04-08 19:44:05,207 - INFO - Página 486/500 processada.
# 2024-04-08 19:44:06,025 - INFO - Página 487/500 processada.
# 2024-04-08 19:44:06,944 - INFO - Página 488/500 processada.
# 2024-04-08 19:44:07,866 - INFO - Página 489/500 processada.
# 2024-04-08 19:44:08,584 - INFO - Página 490/500 processada.
# 2024-04-08 19:44:09,607 - INFO - Página 491/500 processada.
# 2024-04-08 19:44:10,528 - INFO - Página 492/500 processada.
# 2024-04-08 19:44:11,574 - INFO - Página 493/500 processada.
# 2024-04-08 19:44:12,353 - INFO - Página 494/500 processada.
# 2024-04-08 19:44:13,293 - INFO - Página 495/500 processada.
# 2024-04-08 19:44:14,113 - INFO - Página 496/500 processada.
# 2024-04-08 19:44:15,028 - INFO - Página 497/500 processada.
# 2024-04-08 19:44:16,065 - INFO - Página 498/500 processada.
# 2024-04-08 19:44:16,977 - INFO - Página 499/500 processada.
# 2024-04-08 19:44:17,692 - INFO - Página 500/500 processada.
# 2024-04-08 19:44:17,909 - INFO - A tabela contratos não existe. Criando...
# 2024-04-08 19:44:17,964 - INFO - A tabela convenios não existe. Criando...
# 2024-04-08 19:44:35,027 - INFO - Dados inseridos na tabela temporária stage.contratos_temp_stage.
# 2024-04-08 19:45:58,143 - INFO - Dados inseridos na tabela stage.contratos com sucesso.
# 2024-04-08 19:45:58,155 - INFO - Tabela temporária stage.contratos_temp_stage removida com sucesso.
# 2024-04-08 19:46:03,392 - INFO - Dados inseridos na tabela temporária stage.convenios_temp_stage.
# 2024-04-08 19:46:23,810 - INFO - Dados inseridos na tabela stage.convenios com sucesso.
# 2024-04-08 19:46:23,821 - INFO - Tabela temporária stage.convenios_temp_stage removida com sucesso.
