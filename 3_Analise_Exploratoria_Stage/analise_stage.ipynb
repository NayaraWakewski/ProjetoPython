# %%
from sqlalchemy import create_engine
import pandas as pd
import logging

# %%
# Configuração de logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# %%
# Conexão com o banco de dados
engine = create_engine('postgresql://airflow:airflow@127.0.0.1:5432/airflow', echo=False)

# %%
# Função para criar DataFrame a partir de uma tabela no PostgreSQL, incluindo o esquema
def criar_dataframe(nome_tabela, engine, schema='stage'):
    query = f"SELECT * FROM {schema}.{nome_tabela};"
    try:
        df = pd.read_sql_query(query, engine)
        logging.info(f"DataFrame criado para a tabela {schema}.{nome_tabela} com {len(df)} linhas.")
        return df
    except Exception as e:
        logging.error(f"Erro ao criar DataFrame da tabela {schema}.{nome_tabela}: {e}")
        return pd.DataFrame()

if __name__ == "__main__":
    # Criar DataFrames para as tabelas 'contratos' e 'convenios' no esquema 'stage'
    df_contratos = criar_dataframe('contratos', engine, 'stage')
    df_convenios = criar_dataframe('convenios', engine, 'stage')
# Out:
# 2024-04-08 14:33:04,102 - INFO - DataFrame criado para a tabela stage.contratos com 10000 linhas.
# 2024-04-08 14:33:04,192 - INFO - DataFrame criado para a tabela stage.convenios com 2500 linhas.

# %%
#Consultando as 5 primeiras linhas.
df_contratos.head(5)
# Out:
#        id cod_concedente cod_financiador cod_gestora cod_orgao cod_secretaria  \
# 0  371917         228011          805489      220001  22000000       22000000
# 1  435305         220001            3215      220001  22000000       22000000
# 2  378018         240001          318374      241521  24200364       24000000
# 3  518156         241331            2619      241331  24200224       24000000
# 4  443599         240001          126835      240401  24200004       24000000
#
#   decricao_modalidade                                   descricao_objeto  \
# 0            DISPENSA  aquisição de gêneros da agricultura familiar p...
# 1     INEXIGIBILIDADE  O presente contrato tem por objetivo a contrat...
# 2              PREGÃO       AQUISIÇÃO DE FILMES RADIOLÓGICOS PARA O IPC.
# 3              PREGÃO  RECURSO DESTINADO AQUISIÇÃO DE MATERIAL DE LAB...
# 4              PREGÃO  AQUISIÇÃO DE XMTVI MAXAMAID PARA ATENDER DEMAN...
#
#                        descricao_tipo                          descricao_url  \
# 0                            CONTRATO  20191106.1108545.Integra.CONTRATO.pdf
# 1                            CONTRATO  20211111.1190722.Integra.CONTRATO.pdf
# 2                            CONTRATO  20200623.1124263.Integra.CONTRATO.pdf
# 3  DESPESA.SEM.INSTRUMENTO.CONTRATUAL                            Sem Íntegra
# 4  DESPESA.SEM.INSTRUMENTO.CONTRATUAL                            Sem Íntegra
#
#    ...            data_publicacao_doe  \
# 0  ...  2019-11-20T00:00:00.000-03:00
# 1  ...  2021-11-11T00:00:00.000-03:00
# 2  ...  2020-06-26T00:00:00.000-03:00
# 3  ...  2023-08-22T13:53:26.000-03:00
# 4  ...  2022-10-21T13:49:50.000-03:00
#
#                                descricao_nome_credor isn_parte_origem  \
# 0  COOPERATIVA AGROPECUARIA E DE SERVICOS NOSSA S...            85565
# 1  SINDICATO DAS EMPRESAS DE TRANSPORTES   DE PAS...           202624
# 2  CARESTREAM DO BRASIL COMERCIO E SERVIÇOS DE PR...           203041
# 3                 IMPORTEC IMPORTADORA CEARENSE LTDA           321253
# 4                ART MEDICA COM E REP PROD HOST LTDA           203041
#
#    data_auditoria          data_termino_original  \
# 0      2022-09-16  2020-11-19T00:00:00.000-03:00
# 1      2022-09-21  2022-05-10T00:00:00.000-03:00
# 2      2022-09-16  2021-06-18T00:00:00.000-03:00
# 3      2023-08-22  2023-12-31T00:00:00.000-03:00
# 4      2023-01-18  2022-12-31T00:00:00.000-03:00
#
#                      data_inicio data_rescisao confidential  \
# 0  2019-11-20T00:00:00.000-03:00          None        False
# 1  2021-11-10T00:00:00.000-03:00          None        False
# 2  2020-06-18T00:00:00.000-03:00          None        False
# 3  2023-06-29T00:00:00.000-03:00          None        False
# 4  2022-02-15T00:00:00.000-03:00          None        False
#
#           gestor_contrato  data_finalizacao_prestacao_contas
# 0                    None                               None
# 1  WESLEY CAVALCANTE MELO                               None
# 2                    None                               None
# 3                    None                               None
# 4                    None                               None
#
# [5 rows x 60 columns]

# %%
#Consultando as 5 primeiras linhas.
df_convenios.head(5)
# Out:
#        id cod_concedente cod_financiador cod_gestora cod_orgao cod_secretaria  \
# 0  197593         240001          860040      240401  24200004       24000000
# 1  442708         081401          860047      081401  43200007       43000000
# 2  445357         081401          860030      081401  43200007       43000000
# 3  484742         270001          881196      270401  27200004       27000000
# 4  236189         080101          860083      080101  08200001       08000000
#
#   decricao_modalidade                                   descricao_objeto  \
# 0         USO INTERNO  Celebrar Termo de Ajuste com a Prefeitura Muni...
# 1         USO INTERNO  Pavimentação Asfáltica no Município de Chorozi...
# 2         USO INTERNO  Pavimentação em Pedra Tosca no Município de Br...
# 3         USO INTERNO  Constitui objeto do presente TERMO DE EXECUÇÃO...
# 4         USO INTERNO  Construção de uma passagem molhada sobre o Rio...
#
#      descricao_tipo                                  descricao_url  ...  \
# 0      TERMO.AJUSTE        2010624.632222.Integra.TERMO.AJUSTE.pdf  ...
# 1  CONVENIO.DESPESA  20211223.1197033.Integra.CONVENIO.DESPESA.pdf  ...
# 2  CONVENIO.DESPESA  20220314.1201834.Integra.CONVENIO.DESPESA.pdf  ...
# 3  CONVENIO.DESPESA  20221111.1245332.Integra.CONVENIO.DESPESA.pdf  ...
# 4  CONVENIO.DESPESA                    2009128.478857.Convenio.pdf  ...
#
#              data_publicacao_doe            descricao_nome_credor  \
# 0  2010-06-29T00:00:00.000-03:00           PREF MUNIC DE CASCAVEL
# 1  2022-01-04T00:00:00.000-03:00         PREF MUNIC DE CHOROZINHO
# 2  2022-04-08T00:00:00.000-03:00        PREF MUNIC DE BREJO SANTO
# 3  2022-11-17T00:00:00.000-03:00  FRANCISCO ELIEZIO PEREIRA LIMA
# 4  2009-12-17T00:00:00.000-03:00            PREF MUNIC DE ITAPAJE
#
#   isn_parte_origem  data_auditoria          data_termino_original  \
# 0           203041      2024-04-06  2010-12-31T00:00:00.000-03:00
# 1           660288      2024-04-08  2022-12-22T00:00:00.000-03:00
# 2           660288      2024-04-08  2023-03-10T00:00:00.000-03:00
# 3           203134      2024-04-08  2023-11-11T00:00:00.000-03:00
# 4           202525      2024-04-06  2010-02-28T00:00:00.000-03:00
#
#                      data_inicio data_rescisao confidential  \
# 0  2010-06-23T00:00:00.000-03:00          None        false
# 1  2021-12-22T00:00:00.000-03:00          None        false
# 2  2022-03-10T00:00:00.000-03:00          None        false
# 3  2022-11-11T00:00:00.000-03:00          None        false
# 4  2009-12-03T00:00:00.000-03:00          None        false
#
#                       gestor_contrato  data_finalizacao_prestacao_contas
# 0  MANOEL FRANCISCO DE CARVALHO LOPES                               None
# 1                                None                         2023-08-31
# 2                                None                               None
# 3                  FABIANO DOS SANTOS                               None
# 4                                None                               None
#
# [5 rows x 60 columns]

# %%
#Consultando as 5 ultimas linhas.
df_contratos.tail(5)
# Out:
#           id cod_concedente cod_financiador cod_gestora cod_orgao  \
# 9995  154214         310501          355520      310501  31200005
# 9996  483739         228252          797884      220001  22000000
# 9997  291410         241281          824058      241281  24200184
# 9998  459264         241281            6841      241281  24200184
# 9999  474494         100601          901725      100606  10200006
#
#      cod_secretaria decricao_modalidade  \
# 9995       31000000            CONCURSO
# 9996       22000000       CARTA CONVITE
# 9997       24000000              PREGÃO
# 9998       24000000              PREGÃO
# 9999       10000000              PREGÃO
#
#                                        descricao_objeto  \
# 9995  Ampliar o índice de inovação tecnológica das e...
# 9996  AQUISIÇÃO DE MATERIAL DE COPA E COZINHA E PROL...
# 9997  AQUISIÇÃO DE MEDICAMENTO PARA O HOSPITAL GERAL...
# 9998  AQUISIÇÃO DE MATERIAL MÉDICO HOSPITALAR, PARA ...
# 9999  Aquisição de 40 (quarenta) aeronaves remotamen...
#
#                           descricao_tipo  \
# 9995                  CONTRATO.SUBVENCAO
# 9996                            CONTRATO
# 9997  DESPESA.SEM.INSTRUMENTO.CONTRATUAL
# 9998  DESPESA.SEM.INSTRUMENTO.CONTRATUAL
# 9999                            CONTRATO
#
#                                        descricao_url  ...  \
# 9995  20120518.821780.Integra.CONTRATO.SUBVENCAO.pdf  ...
# 9996           20221026.1241298.Integra.CONTRATO.pdf  ...
# 9997                                     Sem Íntegra  ...
# 9998                                     Sem Íntegra  ...
# 9999           20220909.1228261.Integra.CONTRATO.pdf  ...
#
#                 data_publicacao_doe  \
# 9995  2012-05-31T00:00:00.000-03:00
# 9996  2022-11-10T00:00:00.000-03:00
# 9997  2020-03-11T09:00:34.000-03:00
# 9998  2023-03-09T10:38:17.000-03:00
# 9999  2022-09-14T00:00:00.000-03:00
#
#                                   descricao_nome_credor isn_parte_origem  \
# 9995                              VERDE TECNOLOGIA LTDA           203194
# 9996                               ZILFRANIO A DE SOUSA            89299
# 9997             NDS DISTRIBUIDORA DE MEDICAMENTOS LTDA           321261
# 9998  POINT SUTURE DO BRASIL INDUSTRIA DE FIOS CIRUR...           321261
# 9999     DT OFFICE - DISTRIBUIDOR DE ELETRONICOS EIRELI           411609
#
#       data_auditoria          data_termino_original  \
# 9995      2022-09-16  2014-04-12T00:00:00.000-03:00
# 9996      2023-10-10  2023-10-09T00:00:00.000-03:00
# 9997      2022-09-16  2018-12-31T00:00:00.000-03:00
# 9998      2023-03-09  2022-12-31T00:00:00.000-03:00
# 9999      2023-04-25  2022-12-31T00:00:00.000-03:00
#
#                         data_inicio data_rescisao confidential  \
# 9995  2012-04-13T00:00:00.000-03:00          None        False
# 9996  2022-10-10T00:00:00.000-03:00          None        False
# 9997  2018-07-04T00:00:00.000-03:00          None        False
# 9998  2022-05-27T00:00:00.000-03:00          None        False
# 9999  2022-09-09T00:00:00.000-03:00          None        False
#
#                               gestor_contrato  \
# 9995  HAROLDO RODRIGUES DE ALBUQUERQUE JUNIOR
# 9996         CLAUDENIA SOARES DE SOUSA CASTRO
# 9997                                     None
# 9998                                     None
# 9999                                     None
#
#       data_finalizacao_prestacao_contas
# 9995                               None
# 9996                               None
# 9997                               None
# 9998                               None
# 9999                               None
#
# [5 rows x 60 columns]

# %%
#Consultando as 5 ultimas linhas.
df_convenios.tail(5)
# Out:
#           id cod_concedente cod_financiador cod_gestora cod_orgao  \
# 2495  443491         240001          860026      240401  24200004
# 2496   93033         300001          860022      300001  30000000
# 2497  107133         240001          860036      240401  24200004
# 2498  159126         270001          860022      270401  27200004
# 2499  149962         430001          860183      430001  43000000
#
#      cod_secretaria decricao_modalidade  \
# 2495       24000000         USO INTERNO
# 2496       30000000         USO INTERNO
# 2497       24000000         USO INTERNO
# 2498       27000000         USO INTERNO
# 2499       43000000         USO INTERNO
#
#                                        descricao_objeto    descricao_tipo  \
# 2495  REALIZAÇÃO DE PROCEDIMENTOS MEDICO HOSPITALARE...  CONVENIO.DESPESA
# 2496  O presente convênio tem por objetivo geral o e...  CONVENIO.DESPESA
# 2497  Aquisição de Ambulância para o município de Ca...      TERMO.AJUSTE
# 2498  Constitui objeto do presente Convênio, que o E...  CONVENIO.DESPESA
# 2499  Firmar Temo de Ajuste com a Prefeitura de Groa...      TERMO.AJUSTE
#
#                                       descricao_url  ...  \
# 2495  20220209.1198410.Integra.CONVENIO.DESPESA.pdf  ...
# 2496   20140519.926405.Integra.CONVENIO.DESPESA.pdf  ...
# 2497      20180425.1042384.Integra.TERMO.AJUSTE.PDF  ...
# 2498   20120423.818020.Integra.CONVENIO.DESPESA.pdf  ...
# 2499       20120621.830896.Integra.TERMO.AJUSTE.pdf  ...
#
#                 data_publicacao_doe   descricao_nome_credor isn_parte_origem  \
# 2495  2022-02-17T00:00:00.000-03:00  PREF MUNIC DE BATURITE           203041
# 2496  2014-05-21T00:00:00.000-03:00  PREF MUNIC DE BARBALHA           203172
# 2497  2018-05-08T00:00:00.000-03:00    PREF MUNIC DE CARIRE           203041
# 2498  2012-05-03T00:00:00.000-03:00  PREF MUNIC DE BARBALHA           203134
# 2499  2012-07-06T00:00:00.000-03:00  PREF MUNIC DE GROAIRAS           203478
#
#       data_auditoria          data_termino_original  \
# 2495      2024-04-08  2023-02-09T00:00:00.000-03:00
# 2496      2024-04-06  2014-07-14T00:00:00.000-03:00
# 2497      2024-04-08  2019-02-18T00:00:00.000-03:00
# 2498      2024-04-06  2012-06-30T00:00:00.000-03:00
# 2499      2024-04-06  2013-06-05T00:00:00.000-03:00
#
#                         data_inicio data_rescisao confidential  \
# 2495  2022-02-09T00:00:00.000-03:00          None        false
# 2496  2014-05-16T00:00:00.000-03:00          None        false
# 2497  2018-04-24T00:00:00.000-03:00          None        false
# 2498  2012-02-17T00:00:00.000-03:00          None        false
# 2499  2012-06-05T00:00:00.000-03:00          None        false
#
#              gestor_contrato  data_finalizacao_prestacao_contas
# 2495                    None                               None
# 2496   ANDRÉA DE SOUZA BRAGA                               None
# 2497                    None                         2019-11-28
# 2498  FABRÍCIO VIDAL DE LIMA                               None
# 2499     JOSÉ VAGNER MACHADO                               None
#
# [5 rows x 60 columns]

# %%
df_convenios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 60 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   id                                 2500 non-null   int64
#  1   cod_concedente                     2500 non-null   object
#  2   cod_financiador                    2500 non-null   object
#  3   cod_gestora                        2500 non-null   object
#  4   cod_orgao                          2500 non-null   object
#  5   cod_secretaria                     2500 non-null   object
#  6   decricao_modalidade                2500 non-null   object
#  7   descricao_objeto                   2500 non-null   object
#  8   descricao_tipo                     2500 non-null   object
#  9   descricao_url                      2499 non-null   object
#  10  data_assinatura                    2500 non-null   object
#  11  data_processamento                 2500 non-null   object
#  12  data_termino                       2500 non-null   object
#  13  flg_tipo                           2500 non-null   int64
#  14  isn_parte_destino                  2500 non-null   int64
#  15  isn_sic                            2500 non-null   int64
#  16  num_spu                            2215 non-null   object
#  17  valor_contrato                     2500 non-null   object
#  18  isn_modalidade                     2500 non-null   int64
#  19  isn_entidade                       2500 non-null   int64
#  20  tipo_objeto                        1739 non-null   object
#  21  num_spu_licitacao                  0 non-null      object
#  22  descricao_justificativa            2500 non-null   object
#  23  valor_can_rstpg                    2500 non-null   object
#  24  data_publicacao_portal             2500 non-null   object
#  25  descricao_url_pltrb                2499 non-null   object
#  26  descricao_url_ddisp                2499 non-null   object
#  27  descricao_url_inexg                2499 non-null   object
#  28  cod_plano_trabalho                 1061 non-null   object
#  29  num_certidao                       0 non-null      object
#  30  descriaco_edital                   2500 non-null   object
#  31  cpf_cnpj_financiador               2500 non-null   object
#  32  num_contrato                       2429 non-null   object
#  33  valor_original_concedente          2500 non-null   object
#  34  valor_original_contrapartida       2500 non-null   object
#  35  valor_atualizado_concedente        2500 non-null   object
#  36  valor_atualizado_contrapartida     2500 non-null   object
#  37  created_at                         2500 non-null   object
#  38  updated_at                         2500 non-null   object
#  39  plain_num_contrato                 2429 non-null   object
#  40  calculated_valor_aditivo           2500 non-null   object
#  41  calculated_valor_ajuste            2500 non-null   object
#  42  calculated_valor_empenhado         2500 non-null   object
#  43  calculated_valor_pago              2500 non-null   object
#  44  contract_type                      2500 non-null   object
#  45  infringement_status                2500 non-null   int64
#  46  cod_financiador_including_zeroes   2500 non-null   object
#  47  accountability_status              2500 non-null   object
#  48  plain_cpf_cnpj_financiador         2500 non-null   object
#  49  descricao_situacao                 2500 non-null   object
#  50  data_publicacao_doe                2481 non-null   object
#  51  descricao_nome_credor              2500 non-null   object
#  52  isn_parte_origem                   2500 non-null   object
#  53  data_auditoria                     2499 non-null   object
#  54  data_termino_original              2499 non-null   object
#  55  data_inicio                        2499 non-null   object
#  56  data_rescisao                      25 non-null     object
#  57  confidential                       2499 non-null   object
#  58  gestor_contrato                    852 non-null    object
#  59  data_finalizacao_prestacao_contas  588 non-null    object
# dtypes: int64(7), object(53)
# memory usage: 1.1+ MB

# %%
df_contratos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 60 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   id                                 10000 non-null  int64
#  1   cod_concedente                     10000 non-null  object
#  2   cod_financiador                    10000 non-null  object
#  3   cod_gestora                        10000 non-null  object
#  4   cod_orgao                          10000 non-null  object
#  5   cod_secretaria                     10000 non-null  object
#  6   decricao_modalidade                10000 non-null  object
#  7   descricao_objeto                   10000 non-null  object
#  8   descricao_tipo                     10000 non-null  object
#  9   descricao_url                      10000 non-null  object
#  10  data_assinatura                    10000 non-null  object
#  11  data_processamento                 10000 non-null  object
#  12  data_termino                       10000 non-null  object
#  13  flg_tipo                           10000 non-null  int64
#  14  isn_parte_destino                  10000 non-null  int64
#  15  isn_sic                            10000 non-null  int64
#  16  num_spu                            9848 non-null   object
#  17  valor_contrato                     10000 non-null  object
#  18  isn_modalidade                     10000 non-null  int64
#  19  isn_entidade                       10000 non-null  int64
#  20  tipo_objeto                        9583 non-null   object
#  21  num_spu_licitacao                  9152 non-null   object
#  22  descricao_justificativa            10000 non-null  object
#  23  valor_can_rstpg                    10000 non-null  object
#  24  data_publicacao_portal             10000 non-null  object
#  25  descricao_url_pltrb                10000 non-null  object
#  26  descricao_url_ddisp                10000 non-null  object
#  27  descricao_url_inexg                10000 non-null  object
#  28  cod_plano_trabalho                 0 non-null      object
#  29  num_certidao                       9895 non-null   object
#  30  descriaco_edital                   10000 non-null  object
#  31  cpf_cnpj_financiador               10000 non-null  object
#  32  num_contrato                       2873 non-null   object
#  33  valor_original_concedente          10000 non-null  object
#  34  valor_original_contrapartida       10000 non-null  object
#  35  valor_atualizado_concedente        10000 non-null  object
#  36  valor_atualizado_contrapartida     10000 non-null  object
#  37  created_at                         10000 non-null  object
#  38  updated_at                         10000 non-null  object
#  39  plain_num_contrato                 2873 non-null   object
#  40  calculated_valor_aditivo           9999 non-null   object
#  41  calculated_valor_ajuste            9999 non-null   object
#  42  calculated_valor_empenhado         9999 non-null   object
#  43  calculated_valor_pago              10000 non-null  object
#  44  contract_type                      10000 non-null  object
#  45  infringement_status                10000 non-null  int64
#  46  cod_financiador_including_zeroes   10000 non-null  object
#  47  accountability_status              0 non-null      object
#  48  plain_cpf_cnpj_financiador         10000 non-null  object
#  49  descricao_situacao                 10000 non-null  object
#  50  data_publicacao_doe                10000 non-null  object
#  51  descricao_nome_credor              10000 non-null  object
#  52  isn_parte_origem                   10000 non-null  object
#  53  data_auditoria                     9998 non-null   object
#  54  data_termino_original              9999 non-null   object
#  55  data_inicio                        9999 non-null   object
#  56  data_rescisao                      29 non-null     object
#  57  confidential                       10000 non-null  bool
#  58  gestor_contrato                    518 non-null    object
#  59  data_finalizacao_prestacao_contas  0 non-null      object
# dtypes: bool(1), int64(7), object(52)
# memory usage: 4.5+ MB

# %%
# Contagem de valores nulos para cada coluna em df_convenios
nulos_convenios = df_convenios.isnull().sum()
print("Contagem de valores NULOS em cada coluna de df_convenios:")
print(nulos_convenios)
# Out:
# Contagem de valores NULOS em cada coluna de df_convenios:
# id                                      0
# cod_concedente                          0
# cod_financiador                         0
# cod_gestora                             0
# cod_orgao                               0
# cod_secretaria                          0
# decricao_modalidade                     0
# descricao_objeto                        0
# descricao_tipo                          0
# descricao_url                           1
# data_assinatura                         0
# data_processamento                      0
# data_termino                            0
# flg_tipo                                0
# isn_parte_destino                       0
# isn_sic                                 0
# num_spu                               285
# valor_contrato                          0
# isn_modalidade                          0
# isn_entidade                            0
# tipo_objeto                           761
# num_spu_licitacao                    2500
# descricao_justificativa                 0
# valor_can_rstpg                         0
# data_publicacao_portal                  0
# descricao_url_pltrb                     1
# descricao_url_ddisp                     1
# descricao_url_inexg                     1
# cod_plano_trabalho                   1439
# num_certidao                         2500
# descriaco_edital                        0
# cpf_cnpj_financiador                    0
# num_contrato                           71
# valor_original_concedente               0
# valor_original_contrapartida            0
# valor_atualizado_concedente             0
# valor_atualizado_contrapartida          0
# created_at                              0
# updated_at                              0
# plain_num_contrato                     71
# calculated_valor_aditivo                0
# calculated_valor_ajuste                 0
# calculated_valor_empenhado              0
# calculated_valor_pago                   0
# contract_type                           0
# infringement_status                     0
# cod_financiador_including_zeroes        0
# accountability_status                   0
# plain_cpf_cnpj_financiador              0
# descricao_situacao                      0
# data_publicacao_doe                    19
# descricao_nome_credor                   0
# isn_parte_origem                        0
# data_auditoria                          1
# data_termino_original                   1
# data_inicio                             1
# data_rescisao                        2475
# confidential                            1
# gestor_contrato                      1648
# data_finalizacao_prestacao_contas    1912
# dtype: int64

# %%
# Contagem de valores nulos para cada coluna em df_contratos
nulos_contratos = df_contratos.isnull().sum()
print("Contagem de valores NULOS em cada coluna de df_contratos:")
print(nulos_contratos)
# Out:
# Contagem de valores NULOS em cada coluna de df_contratos:
# id                                       0
# cod_concedente                           0
# cod_financiador                          0
# cod_gestora                              0
# cod_orgao                                0
# cod_secretaria                           0
# decricao_modalidade                      0
# descricao_objeto                         0
# descricao_tipo                           0
# descricao_url                            0
# data_assinatura                          0
# data_processamento                       0
# data_termino                             0
# flg_tipo                                 0
# isn_parte_destino                        0
# isn_sic                                  0
# num_spu                                152
# valor_contrato                           0
# isn_modalidade                           0
# isn_entidade                             0
# tipo_objeto                            417
# num_spu_licitacao                      848
# descricao_justificativa                  0
# valor_can_rstpg                          0
# data_publicacao_portal                   0
# descricao_url_pltrb                      0
# descricao_url_ddisp                      0
# descricao_url_inexg                      0
# cod_plano_trabalho                   10000
# num_certidao                           105
# descriaco_edital                         0
# cpf_cnpj_financiador                     0
# num_contrato                          7127
# valor_original_concedente                0
# valor_original_contrapartida             0
# valor_atualizado_concedente              0
# valor_atualizado_contrapartida           0
# created_at                               0
# updated_at                               0
# plain_num_contrato                    7127
# calculated_valor_aditivo                 1
# calculated_valor_ajuste                  1
# calculated_valor_empenhado               1
# calculated_valor_pago                    0
# contract_type                            0
# infringement_status                      0
# cod_financiador_including_zeroes         0
# accountability_status                10000
# plain_cpf_cnpj_financiador               0
# descricao_situacao                       0
# data_publicacao_doe                      0
# descricao_nome_credor                    0
# isn_parte_origem                         0
# data_auditoria                           2
# data_termino_original                    1
# data_inicio                              1
# data_rescisao                         9971
# confidential                             0
# gestor_contrato                       9482
# data_finalizacao_prestacao_contas    10000
# dtype: int64

# %%
#Consulta de Duplicados - DF_CONTRATOS

# Definição das chaves únicas
colunas_chave_unica_contratos = ['cpf_cnpj_financiador', 'num_contrato', 'data_assinatura']

# Verificação de duplicatas
duplicadas_contratos = df_contratos.duplicated(subset=colunas_chave_unica_contratos, keep=False)

# Contagem das linhas duplicadas
quantidade_duplicadas_contratos = duplicadas_contratos.sum()

# Exibição da quantidade de linhas duplicadas
print("Quantidade de linhas duplicadas em df_contratos com base nas chaves únicas:")
print(quantidade_duplicadas_contratos)
# Out:
# Quantidade de linhas duplicadas em df_contratos com base nas chaves únicas:
# 1695

# %%
#Consulta de Duplicados - DF_CONVENIOS

# Definição das chaves únicas
colunas_chave_unica_contratos = ['cpf_cnpj_financiador', 'num_contrato', 'data_assinatura']

# Verificação de duplicatas
duplicadas_convenios = df_convenios.duplicated(subset=colunas_chave_unica_contratos, keep=False)

# Contagem das linhas duplicadas
quantidade_duplicadas_convenios = duplicadas_convenios.sum()

# Exibição da quantidade de linhas duplicadas
print("Quantidade de linhas duplicadas em df_convenios com base nas chaves únicas:")
print(quantidade_duplicadas_convenios)
# Out:
# Quantidade de linhas duplicadas em df_convenios com base nas chaves únicas:
# 9
