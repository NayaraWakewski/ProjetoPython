# %%
from sqlalchemy import create_engine
import pandas as pd
import logging

# %%
# Configuração de logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# %%
# Conexão com o banco de dados
engine = create_engine('postgresql://airflow:airflow@127.0.0.1:5432/airflow', echo=False)

# %%
# Função para criar DataFrame a partir de uma tabela no PostgreSQL, incluindo o esquema
def criar_dataframe(nome_tabela, engine, schema='stage'):
    query = f"SELECT * FROM {schema}.{nome_tabela};"
    try:
        df = pd.read_sql_query(query, engine)
        logging.info(f"DataFrame criado para a tabela {schema}.{nome_tabela} com {len(df)} linhas.")
        return df
    except Exception as e:
        logging.error(f"Erro ao criar DataFrame da tabela {schema}.{nome_tabela}: {e}")
        return pd.DataFrame()

if __name__ == "__main__":
    # Criar DataFrames para as tabelas 'contratos' e 'convenios' no esquema 'stage'
    df_contratos = criar_dataframe('contratos', engine, 'stage')
    df_convenios = criar_dataframe('convenios', engine, 'stage')
# Out:
# 2024-04-07 18:30:38,830 - INFO - DataFrame criado para a tabela stage.contratos com 1000 linhas.
# 2024-04-07 18:30:38,853 - INFO - DataFrame criado para a tabela stage.convenios com 250 linhas.

# %%
#Consultando as 5 primeiras linhas.
df_contratos.head(5)
# Out:
#        id cod_concedente cod_financiador cod_gestora cod_orgao cod_secretaria  \
# 0  371917         228011          805489      220001  22000000       22000000
# 1  435305         220001            3215      220001  22000000       22000000
# 2  378018         240001          318374      241521  24200364       24000000
# 3  518156         241331            2619      241331  24200224       24000000
# 4  443599         240001          126835      240401  24200004       24000000
#
#   decricao_modalidade                                   descricao_objeto  \
# 0            DISPENSA  aquisição de gêneros da agricultura familiar p...
# 1     INEXIGIBILIDADE  O presente contrato tem por objetivo a contrat...
# 2              PREGÃO       AQUISIÇÃO DE FILMES RADIOLÓGICOS PARA O IPC.
# 3              PREGÃO  RECURSO DESTINADO AQUISIÇÃO DE MATERIAL DE LAB...
# 4              PREGÃO  AQUISIÇÃO DE XMTVI MAXAMAID PARA ATENDER DEMAN...
#
#                        descricao_tipo                          descricao_url  \
# 0                            CONTRATO  20191106.1108545.Integra.CONTRATO.pdf
# 1                            CONTRATO  20211111.1190722.Integra.CONTRATO.pdf
# 2                            CONTRATO  20200623.1124263.Integra.CONTRATO.pdf
# 3  DESPESA.SEM.INSTRUMENTO.CONTRATUAL                            Sem Íntegra
# 4  DESPESA.SEM.INSTRUMENTO.CONTRATUAL                            Sem Íntegra
#
#    ...            data_publicacao_doe  \
# 0  ...  2019-11-20T00:00:00.000-03:00
# 1  ...  2021-11-11T00:00:00.000-03:00
# 2  ...  2020-06-26T00:00:00.000-03:00
# 3  ...  2023-08-22T13:53:26.000-03:00
# 4  ...  2022-10-21T13:49:50.000-03:00
#
#                                descricao_nome_credor isn_parte_origem  \
# 0  COOPERATIVA AGROPECUARIA E DE SERVICOS NOSSA S...            85565
# 1  SINDICATO DAS EMPRESAS DE TRANSPORTES   DE PAS...           202624
# 2  CARESTREAM DO BRASIL COMERCIO E SERVIÇOS DE PR...           203041
# 3                 IMPORTEC IMPORTADORA CEARENSE LTDA           321253
# 4                ART MEDICA COM E REP PROD HOST LTDA           203041
#
#    data_auditoria          data_termino_original  \
# 0      2022-09-16  2020-11-19T00:00:00.000-03:00
# 1      2022-09-21  2022-05-10T00:00:00.000-03:00
# 2      2022-09-16  2021-06-18T00:00:00.000-03:00
# 3      2023-08-22  2023-12-31T00:00:00.000-03:00
# 4      2023-01-18  2022-12-31T00:00:00.000-03:00
#
#                      data_inicio data_rescisao confidential  \
# 0  2019-11-20T00:00:00.000-03:00          None        False
# 1  2021-11-10T00:00:00.000-03:00          None        False
# 2  2020-06-18T00:00:00.000-03:00          None        False
# 3  2023-06-29T00:00:00.000-03:00          None        False
# 4  2022-02-15T00:00:00.000-03:00          None        False
#
#           gestor_contrato  data_finalizacao_prestacao_contas
# 0                    None                               None
# 1  WESLEY CAVALCANTE MELO                               None
# 2                    None                               None
# 3                    None                               None
# 4                    None                               None
#
# [5 rows x 60 columns]

# %%
#Consultando as 5 primeiras linhas.
df_convenios.head(5)
# Out:
#        id cod_concedente cod_financiador cod_gestora cod_orgao cod_secretaria  \
# 0  197593         240001          860040      240401  24200004       24000000
# 1  442708         081401          860047      081401  43200007       43000000
# 2  445357         081401          860030      081401  43200007       43000000
# 3  484742         270001          881196      270401  27200004       27000000
# 4  236189         080101          860083      080101  08200001       08000000
#
#   decricao_modalidade                                   descricao_objeto  \
# 0         USO INTERNO  Celebrar Termo de Ajuste com a Prefeitura Muni...
# 1         USO INTERNO  Pavimentação Asfáltica no Município de Chorozi...
# 2         USO INTERNO  Pavimentação em Pedra Tosca no Município de Br...
# 3         USO INTERNO  Constitui objeto do presente TERMO DE EXECUÇÃO...
# 4         USO INTERNO  Construção de uma passagem molhada sobre o Rio...
#
#      descricao_tipo                                  descricao_url  ...  \
# 0      TERMO.AJUSTE        2010624.632222.Integra.TERMO.AJUSTE.pdf  ...
# 1  CONVENIO.DESPESA  20211223.1197033.Integra.CONVENIO.DESPESA.pdf  ...
# 2  CONVENIO.DESPESA  20220314.1201834.Integra.CONVENIO.DESPESA.pdf  ...
# 3  CONVENIO.DESPESA  20221111.1245332.Integra.CONVENIO.DESPESA.pdf  ...
# 4  CONVENIO.DESPESA                    2009128.478857.Convenio.pdf  ...
#
#              data_publicacao_doe            descricao_nome_credor  \
# 0  2010-06-29T00:00:00.000-03:00           PREF MUNIC DE CASCAVEL
# 1  2022-01-04T00:00:00.000-03:00         PREF MUNIC DE CHOROZINHO
# 2  2022-04-08T00:00:00.000-03:00        PREF MUNIC DE BREJO SANTO
# 3  2022-11-17T00:00:00.000-03:00  FRANCISCO ELIEZIO PEREIRA LIMA
# 4  2009-12-17T00:00:00.000-03:00            PREF MUNIC DE ITAPAJE
#
#   isn_parte_origem  data_auditoria          data_termino_original  \
# 0           203041      2024-04-06  2010-12-31T00:00:00.000-03:00
# 1           660288      2024-04-07  2022-12-22T00:00:00.000-03:00
# 2           660288      2024-04-07  2023-03-10T00:00:00.000-03:00
# 3           203134      2024-04-07  2023-11-11T00:00:00.000-03:00
# 4           202525      2024-04-06  2010-02-28T00:00:00.000-03:00
#
#                      data_inicio data_rescisao confidential  \
# 0  2010-06-23T00:00:00.000-03:00          None        false
# 1  2021-12-22T00:00:00.000-03:00          None        false
# 2  2022-03-10T00:00:00.000-03:00          None        false
# 3  2022-11-11T00:00:00.000-03:00          None        false
# 4  2009-12-03T00:00:00.000-03:00          None        false
#
#                       gestor_contrato  data_finalizacao_prestacao_contas
# 0  MANOEL FRANCISCO DE CARVALHO LOPES                               None
# 1                                None                         2023-08-31
# 2                                None                               None
# 3                  FABIANO DOS SANTOS                               None
# 4                                None                               None
#
# [5 rows x 60 columns]

# %%
#Consultando as 5 ultimas linhas.
df_contratos.tail(5)
# Out:
#          id cod_concedente cod_financiador cod_gestora cod_orgao  \
# 995  419599         228122          822862      220001  22000000
# 996  409271         241291          827910      241291  24200214
# 997  378038         240001          875801      240401  24200004
# 998  199060         240001          252712      240401  24200004
# 999  408578         241281          827910      241281  24200184
#
#     cod_secretaria decricao_modalidade  \
# 995       22000000            DISPENSA
# 996       24000000              PREGÃO
# 997       24000000              PREGÃO
# 998       24000000              PREGÃO
# 999       24000000              PREGÃO
#
#                                       descricao_objeto  \
# 995  MATERIAL DE LIMPEZA E PRODUÇÃO DE HIGIENIZAÇÃO...
# 996  Aquisição de medicamentos, de acordo com a ata...
# 997  AQUISIÇÃO DO MEDICAMENTO ACETATO DE OCTREOTIDA...
# 998  contratação de empresa especiliazada para manu...
# 999  AQUISIÇÃO DE MATERIAL FARMACOLÓGICO, PARA O HO...
#
#                          descricao_tipo  \
# 995  DESPESA.SEM.INSTRUMENTO.CONTRATUAL
# 996  DESPESA.SEM.INSTRUMENTO.CONTRATUAL
# 997  DESPESA.SEM.INSTRUMENTO.CONTRATUAL
# 998                            CONTRATO
# 999  DESPESA.SEM.INSTRUMENTO.CONTRATUAL
#
#                                          descricao_url  ...  \
# 995  20210809.1172632.Declaracao.Dispensa.DESPESA.S...  ...
# 996                                        Sem Íntegra  ...
# 997                                        Sem Íntegra  ...
# 998               20100830.647117.Integra.CONTRATO.pdf  ...
# 999                                        Sem Íntegra  ...
#
#                data_publicacao_doe  \
# 995  2022-06-10T11:32:17.000-03:00
# 996  2022-04-01T15:53:48.000-03:00
# 997  2021-09-16T09:12:42.000-03:00
# 998  2010-09-10T00:00:00.000-03:00
# 999  2022-04-04T09:43:45.000-03:00
#
#                           descricao_nome_credor isn_parte_origem  \
# 995                    MARIA EDNA DE SOUZA - ME            85920
# 996  ONCOVIT DISTRIBUIDORA DE MEDICAMENTOS LTDA           321252
# 997                      ELFA MEDICAMENTOS S.A.           203041
# 998  ALSCIENCE ENGENHARIA E REPRESENTAÇÕES LTDA           203041
# 999  ONCOVIT DISTRIBUIDORA DE MEDICAMENTOS LTDA           321261
#
#      data_auditoria          data_termino_original  \
# 995      2022-09-16  2021-12-31T00:00:00.000-03:00
# 996      2022-09-16  2021-12-31T00:00:00.000-03:00
# 997      2022-09-16  2020-12-31T00:00:00.000-03:00
# 998      2022-09-16  2011-09-10T00:00:00.000-03:00
# 999      2022-09-16  2021-12-31T00:00:00.000-03:00
#
#                        data_inicio data_rescisao confidential  \
# 995  2021-08-09T00:00:00.000-03:00          None        False
# 996  2021-03-15T00:00:00.000-03:00          None        False
# 997  2020-06-25T00:00:00.000-03:00          None        False
# 998  2010-09-10T00:00:00.000-03:00          None        False
# 999  2021-03-09T00:00:00.000-03:00          None        False
#
#      gestor_contrato  data_finalizacao_prestacao_contas
# 995             None                               None
# 996             None                               None
# 997             None                               None
# 998             None                               None
# 999             None                               None
#
# [5 rows x 60 columns]

# %%
#Consultando as 5 ultimas linhas.
df_convenios.tail(5)
# Out:
#          id cod_concedente cod_financiador cod_gestora cod_orgao  \
# 245  531785         081401          860075      081401  43200007
# 246  218471         240001          860200      241081  24200464
# 247  110083         210001          831653      210001  21000000
# 248   47991         240001          860014      240401  24200004
# 249  112806         430001          860023      430001  43000000
#
#     cod_secretaria decricao_modalidade  \
# 245       43000000         USO INTERNO
# 246       24000000         USO INTERNO
# 247       21000000         USO INTERNO
# 248       24000000         USO INTERNO
# 249       43000000         USO INTERNO
#
#                                       descricao_objeto    descricao_tipo  \
# 245  PAVIMENTAÇÃO EM PEDRA TOSCA DE DIVERSAS RUAS D...  CONVENIO.DESPESA
# 246  Prestar serviços especializados no bloco da mé...  CONVENIO.DESPESA
# 247  IR 007/2018 - Paulo Freire/FIDA - Fortalecer a...  CONVENIO.DESPESA
# 248  Aquisição de 02 (dois) veículos tipo ambulânci...      TERMO.AJUSTE
# 249  Pavimentação em Pedra Tosca nas ruas Mestre Ju...      TERMO.AJUSTE
#
#                                      descricao_url  ...  \
# 245  20231018.1294308.Integra.CONVENIO.DESPESA.pdf  ...
# 246                     200968.313055.Convenio.pdf  ...
# 247  20180328.1039567.Integra.CONVENIO.DESPESA.pdf  ...
# 248       20160422.983406.Integra.TERMO.AJUSTE.pdf  ...
# 249      20180525.1046412.Integra.TERMO.AJUSTE.pdf  ...
#
#                data_publicacao_doe                 descricao_nome_credor  \
# 245  2023-10-24T00:00:00.000-03:00              PREF MUNIC DE IPAPORANGA
# 246  2009-06-23T00:00:00.000-03:00               INSTITUTO DR JOSE FROTA
# 247  2018-04-05T00:00:00.000-03:00  ASSOCIAÇÃO COMUNITÁRIA RURAL DE ZIPU
# 248  2016-04-27T00:00:00.000-03:00      PREFEITURA MUNICIPAL DE ARARENDA
# 249  2018-06-04T00:00:00.000-03:00                PREF MUNIC DE BARREIRA
#
#     isn_parte_origem  data_auditoria          data_termino_original  \
# 245           660288      2024-04-07  2024-10-18T00:00:00.000-03:00
# 246           203041      2024-04-06  2010-04-04T00:00:00.000-03:00
# 247           203809      2024-04-07  2019-03-22T00:00:00.000-03:00
# 248           203041      2024-04-07  2016-12-30T00:00:00.000-03:00
# 249           203478      2024-04-07  2019-04-24T00:00:00.000-03:00
#
#                        data_inicio data_rescisao confidential  \
# 245  2023-10-18T00:00:00.000-03:00          None        false
# 246  2009-05-04T00:00:00.000-03:00          None        false
# 247  2018-03-23T00:00:00.000-03:00          None        false
# 248  2016-03-16T00:00:00.000-03:00          None        false
# 249  2018-04-24T00:00:00.000-03:00          None        false
#
#                                       gestor_contrato  \
# 245                                              None
# 246                                              None
# 247  MARIA IRIS TAVARES FARIAS - MATRÍCULA 300103-1-0
# 248                                              None
# 249                                              None
#
#      data_finalizacao_prestacao_contas
# 245                               None
# 246                               None
# 247                               None
# 248                         2017-02-10
# 249                         2023-11-27
#
# [5 rows x 60 columns]

# %%
df_convenios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 60 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   id                                 250 non-null    int64
#  1   cod_concedente                     250 non-null    object
#  2   cod_financiador                    250 non-null    object
#  3   cod_gestora                        250 non-null    object
#  4   cod_orgao                          250 non-null    object
#  5   cod_secretaria                     250 non-null    object
#  6   decricao_modalidade                250 non-null    object
#  7   descricao_objeto                   250 non-null    object
#  8   descricao_tipo                     250 non-null    object
#  9   descricao_url                      250 non-null    object
#  10  data_assinatura                    250 non-null    object
#  11  data_processamento                 250 non-null    object
#  12  data_termino                       250 non-null    object
#  13  flg_tipo                           250 non-null    int64
#  14  isn_parte_destino                  250 non-null    int64
#  15  isn_sic                            250 non-null    int64
#  16  num_spu                            236 non-null    object
#  17  valor_contrato                     250 non-null    object
#  18  isn_modalidade                     250 non-null    int64
#  19  isn_entidade                       250 non-null    int64
#  20  tipo_objeto                        203 non-null    object
#  21  num_spu_licitacao                  0 non-null      object
#  22  descricao_justificativa            250 non-null    object
#  23  valor_can_rstpg                    250 non-null    object
#  24  data_publicacao_portal             250 non-null    object
#  25  descricao_url_pltrb                250 non-null    object
#  26  descricao_url_ddisp                250 non-null    object
#  27  descricao_url_inexg                250 non-null    object
#  28  cod_plano_trabalho                 119 non-null    object
#  29  num_certidao                       0 non-null      object
#  30  descriaco_edital                   250 non-null    object
#  31  cpf_cnpj_financiador               250 non-null    object
#  32  num_contrato                       244 non-null    object
#  33  valor_original_concedente          250 non-null    object
#  34  valor_original_contrapartida       250 non-null    object
#  35  valor_atualizado_concedente        250 non-null    object
#  36  valor_atualizado_contrapartida     250 non-null    object
#  37  created_at                         250 non-null    object
#  38  updated_at                         250 non-null    object
#  39  plain_num_contrato                 244 non-null    object
#  40  calculated_valor_aditivo           250 non-null    object
#  41  calculated_valor_ajuste            250 non-null    object
#  42  calculated_valor_empenhado         250 non-null    object
#  43  calculated_valor_pago              250 non-null    object
#  44  contract_type                      250 non-null    object
#  45  infringement_status                250 non-null    int64
#  46  cod_financiador_including_zeroes   250 non-null    object
#  47  accountability_status              250 non-null    object
#  48  plain_cpf_cnpj_financiador         250 non-null    object
#  49  descricao_situacao                 250 non-null    object
#  50  data_publicacao_doe                248 non-null    object
#  51  descricao_nome_credor              250 non-null    object
#  52  isn_parte_origem                   250 non-null    object
#  53  data_auditoria                     250 non-null    object
#  54  data_termino_original              249 non-null    object
#  55  data_inicio                        249 non-null    object
#  56  data_rescisao                      3 non-null      object
#  57  confidential                       249 non-null    object
#  58  gestor_contrato                    97 non-null     object
#  59  data_finalizacao_prestacao_contas  52 non-null     object
# dtypes: int64(7), object(53)
# memory usage: 117.3+ KB

# %%
df_contratos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 60 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   id                                 1000 non-null   int64
#  1   cod_concedente                     1000 non-null   object
#  2   cod_financiador                    1000 non-null   object
#  3   cod_gestora                        1000 non-null   object
#  4   cod_orgao                          1000 non-null   object
#  5   cod_secretaria                     1000 non-null   object
#  6   decricao_modalidade                1000 non-null   object
#  7   descricao_objeto                   1000 non-null   object
#  8   descricao_tipo                     1000 non-null   object
#  9   descricao_url                      1000 non-null   object
#  10  data_assinatura                    1000 non-null   object
#  11  data_processamento                 1000 non-null   object
#  12  data_termino                       1000 non-null   object
#  13  flg_tipo                           1000 non-null   int64
#  14  isn_parte_destino                  1000 non-null   int64
#  15  isn_sic                            1000 non-null   int64
#  16  num_spu                            964 non-null    object
#  17  valor_contrato                     1000 non-null   object
#  18  isn_modalidade                     1000 non-null   int64
#  19  isn_entidade                       1000 non-null   int64
#  20  tipo_objeto                        949 non-null    object
#  21  num_spu_licitacao                  922 non-null    object
#  22  descricao_justificativa            1000 non-null   object
#  23  valor_can_rstpg                    1000 non-null   object
#  24  data_publicacao_portal             1000 non-null   object
#  25  descricao_url_pltrb                1000 non-null   object
#  26  descricao_url_ddisp                1000 non-null   object
#  27  descricao_url_inexg                1000 non-null   object
#  28  cod_plano_trabalho                 0 non-null      object
#  29  num_certidao                       998 non-null    object
#  30  descriaco_edital                   1000 non-null   object
#  31  cpf_cnpj_financiador               1000 non-null   object
#  32  num_contrato                       332 non-null    object
#  33  valor_original_concedente          1000 non-null   object
#  34  valor_original_contrapartida       1000 non-null   object
#  35  valor_atualizado_concedente        1000 non-null   object
#  36  valor_atualizado_contrapartida     1000 non-null   object
#  37  created_at                         1000 non-null   object
#  38  updated_at                         1000 non-null   object
#  39  plain_num_contrato                 332 non-null    object
#  40  calculated_valor_aditivo           1000 non-null   object
#  41  calculated_valor_ajuste            1000 non-null   object
#  42  calculated_valor_empenhado         1000 non-null   object
#  43  calculated_valor_pago              1000 non-null   object
#  44  contract_type                      1000 non-null   object
#  45  infringement_status                1000 non-null   int64
#  46  cod_financiador_including_zeroes   1000 non-null   object
#  47  accountability_status              0 non-null      object
#  48  plain_cpf_cnpj_financiador         1000 non-null   object
#  49  descricao_situacao                 1000 non-null   object
#  50  data_publicacao_doe                1000 non-null   object
#  51  descricao_nome_credor              1000 non-null   object
#  52  isn_parte_origem                   1000 non-null   object
#  53  data_auditoria                     999 non-null    object
#  54  data_termino_original              1000 non-null   object
#  55  data_inicio                        1000 non-null   object
#  56  data_rescisao                      6 non-null      object
#  57  confidential                       1000 non-null   bool
#  58  gestor_contrato                    43 non-null     object
#  59  data_finalizacao_prestacao_contas  0 non-null      object
# dtypes: bool(1), int64(7), object(52)
# memory usage: 462.0+ KB

# %%
# Contagem de valores nulos para cada coluna em df_convenios
nulos_convenios = df_convenios.isnull().sum()
print("Contagem de valores NULOS em cada coluna de df_convenios:")
print(nulos_convenios)
# Out:
# Contagem de valores NULOS em cada coluna de df_convenios:
# id                                     0
# cod_concedente                         0
# cod_financiador                        0
# cod_gestora                            0
# cod_orgao                              0
# cod_secretaria                         0
# decricao_modalidade                    0
# descricao_objeto                       0
# descricao_tipo                         0
# descricao_url                          0
# data_assinatura                        0
# data_processamento                     0
# data_termino                           0
# flg_tipo                               0
# isn_parte_destino                      0
# isn_sic                                0
# num_spu                               14
# valor_contrato                         0
# isn_modalidade                         0
# isn_entidade                           0
# tipo_objeto                           47
# num_spu_licitacao                    250
# descricao_justificativa                0
# valor_can_rstpg                        0
# data_publicacao_portal                 0
# descricao_url_pltrb                    0
# descricao_url_ddisp                    0
# descricao_url_inexg                    0
# cod_plano_trabalho                   131
# num_certidao                         250
# descriaco_edital                       0
# cpf_cnpj_financiador                   0
# num_contrato                           6
# valor_original_concedente              0
# valor_original_contrapartida           0
# valor_atualizado_concedente            0
# valor_atualizado_contrapartida         0
# created_at                             0
# updated_at                             0
# plain_num_contrato                     6
# calculated_valor_aditivo               0
# calculated_valor_ajuste                0
# calculated_valor_empenhado             0
# calculated_valor_pago                  0
# contract_type                          0
# infringement_status                    0
# cod_financiador_including_zeroes       0
# accountability_status                  0
# plain_cpf_cnpj_financiador             0
# descricao_situacao                     0
# data_publicacao_doe                    2
# descricao_nome_credor                  0
# isn_parte_origem                       0
# data_auditoria                         0
# data_termino_original                  1
# data_inicio                            1
# data_rescisao                        247
# confidential                           1
# gestor_contrato                      153
# data_finalizacao_prestacao_contas    198
# dtype: int64

# %%
# Contagem de valores nulos para cada coluna em df_contratos
nulos_contratos = df_contratos.isnull().sum()
print("Contagem de valores NULOS em cada coluna de df_contratos:")
print(nulos_contratos)
# Out:
# Contagem de valores NULOS em cada coluna de df_contratos:
# id                                      0
# cod_concedente                          0
# cod_financiador                         0
# cod_gestora                             0
# cod_orgao                               0
# cod_secretaria                          0
# decricao_modalidade                     0
# descricao_objeto                        0
# descricao_tipo                          0
# descricao_url                           0
# data_assinatura                         0
# data_processamento                      0
# data_termino                            0
# flg_tipo                                0
# isn_parte_destino                       0
# isn_sic                                 0
# num_spu                                36
# valor_contrato                          0
# isn_modalidade                          0
# isn_entidade                            0
# tipo_objeto                            51
# num_spu_licitacao                      78
# descricao_justificativa                 0
# valor_can_rstpg                         0
# data_publicacao_portal                  0
# descricao_url_pltrb                     0
# descricao_url_ddisp                     0
# descricao_url_inexg                     0
# cod_plano_trabalho                   1000
# num_certidao                            2
# descriaco_edital                        0
# cpf_cnpj_financiador                    0
# num_contrato                          668
# valor_original_concedente               0
# valor_original_contrapartida            0
# valor_atualizado_concedente             0
# valor_atualizado_contrapartida          0
# created_at                              0
# updated_at                              0
# plain_num_contrato                    668
# calculated_valor_aditivo                0
# calculated_valor_ajuste                 0
# calculated_valor_empenhado              0
# calculated_valor_pago                   0
# contract_type                           0
# infringement_status                     0
# cod_financiador_including_zeroes        0
# accountability_status                1000
# plain_cpf_cnpj_financiador              0
# descricao_situacao                      0
# data_publicacao_doe                     0
# descricao_nome_credor                   0
# isn_parte_origem                        0
# data_auditoria                          1
# data_termino_original                   0
# data_inicio                             0
# data_rescisao                         994
# confidential                            0
# gestor_contrato                       957
# data_finalizacao_prestacao_contas    1000
# dtype: int64

# %%
#Consulta de Duplicados - DF_CONTRATOS

# Definição das chaves únicas
colunas_chave_unica_contratos = ['cpf_cnpj_financiador', 'num_contrato', 'data_assinatura']

# Verificação de duplicatas
duplicadas_contratos = df_contratos.duplicated(subset=colunas_chave_unica_contratos, keep=False)

# Contagem das linhas duplicadas
quantidade_duplicadas_contratos = duplicadas_contratos.sum()

# Exibição da quantidade de linhas duplicadas
print("Quantidade de linhas duplicadas em df_contratos com base nas chaves únicas:")
print(quantidade_duplicadas_contratos)
# Out:
# Quantidade de linhas duplicadas em df_contratos com base nas chaves únicas:
# 103

# %%
#Consulta de Duplicados - DF_CONVENIOS

# Definição das chaves únicas
colunas_chave_unica_contratos = ['cpf_cnpj_financiador', 'num_contrato', 'data_assinatura']

# Verificação de duplicatas
duplicadas_convenios = df_convenios.duplicated(subset=colunas_chave_unica_contratos, keep=False)

# Contagem das linhas duplicadas
quantidade_duplicadas_convenios = duplicadas_convenios.sum()

# Exibição da quantidade de linhas duplicadas
print("Quantidade de linhas duplicadas em df_convenios com base nas chaves únicas:")
print(quantidade_duplicadas_convenios)
# Out:
# Quantidade de linhas duplicadas em df_convenios com base nas chaves únicas:
# 0
